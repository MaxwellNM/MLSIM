# %% [markdown]
# # II Experimentation on effective data from philippines

# %%
# Initialisations
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
plt.rcParams["figure.figsize"] = (12, 8) # (w, h)
from extraction import *
from preprocess import *
from parameters import *
from  model.MDBN import MDBN
import numpy as np
import time
import pickle
import argparse
from sklearn.metrics import confusion_matrix, accuracy_score
from sklearn.decomposition import PCA
from sklearn.datasets.samples_generator import make_blobs
from sklearn import preprocessing
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## 1. Chargement des données.

# %%
data = {}
data[0] = np.load('.\\data\\phili2017\\features\\origin\\ar.npy'),np.load('.\\data\\phili2017\\labels\\labels_ar.npy')
data[1] = np.load('.\\data\\phili2017\\features\\origin\\si.npy'),np.load('.\\data\\phili2017\\labels\\labels_si.npy')
data[2] = np.load('.\\data\\phili2017\\features\\origin\\vv.npy'),np.load('.\\data\\phili2017\\labels\\labels_vv.npy')
data[3] = np.load('.\\data\\phili2017\\features\\origin\\sg.npy'),np.load('.\\data\\phili2017\\labels\\labels_sg.npy')

# %% [markdown]
# ## 2. Definition des traces d'apprentissages du système

# %%
LS = ['Processing', 'Perception', 'Input', 'Understanding']

# %%
Classes = {} #Style d'apprentissage
Classes[0] = ["Active","Reflective"]
Classes[1] = ["Sensitive","Intuitive"]
Classes[2] = ["Visual","Verbal"] 
Classes[3] = ["Sequential","Global"] 
FSLSM = ["AR","SI","VV","SG"]

# %%
targets = {}
for i in range(0, len(data)):
    targets[i] = data[i][1]

# %%
for i in range(0, len(data)):
    nb1 = (targets[i]==1).sum()
    nb2 = (targets[i]==-1).sum()
    print ("Felder's Dimension: ",LS[i],"\t",Classes [i][0], ": ",nb1, "\n\t\t\t\t\t",Classes [i][1], ": ",nb2)
# Out:
# Felder's Dimension:  Processing 	 Active :  244
# 					 Reflective :  263
# Felder's Dimension:  Perception 	 Sensitive :  159
# 					 Intuitive :  348
# Felder's Dimension:  Input 	 Visual :  388
# 					 Verbal :  119
# Felder's Dimension:  Understanding 	 Sequential :  250
# 					 Global :  257

# %% [markdown]
# ## 3. Test data on dummy classifier

# %%
from sklearn.dummy import DummyClassifier

# %%
def evaluation_surclassifieur_naif(pos):
    X_train, X_test, Y_train, Y_test  = train_test_split(data[pos][0],targets[pos], test_size=0.2,random_state=0)
    # DummyClassifier to predict only target 0
    print("Classifieur Naif pour: ",LS[pos])
    dummy = DummyClassifier(strategy='most_frequent').fit(X_train, Y_train)
    dummy_pred = dummy.predict(X_test)

    # checking unique labels
    print('Style d\'apprentissage majoritaire prédit: ', Classes[pos][int(np.unique(dummy_pred))])

    # checking accuracy
    print('Test score: ', accuracy_score(Y_test, dummy_pred))

# %%
evaluation_surclassifieur_naif(0)
# Out:
# Classifieur Naif pour:  Processing
# Style d'apprentissage majoritaire prédit:  Reflective
# Test score:  0.5490196078431373

# %%
evaluation_surclassifieur_naif(1)
# Out:
# Classifieur Naif pour:  Perception
# Style d'apprentissage majoritaire prédit:  Intuitive
# Test score:  0.7941176470588235

# %%
evaluation_surclassifieur_naif(2)
# Out:
# Classifieur Naif pour:  Input
# Style d'apprentissage majoritaire prédit:  Verbal
# Test score:  0.7254901960784313

# %%
evaluation_surclassifieur_naif(3)
# Out:
# Classifieur Naif pour:  Understanding
# Style d'apprentissage majoritaire prédit:  Global
# Test score:  0.49019607843137253

# %% [markdown]
# ### 4. Test sur modele

# %%
np.random.seed(1337)  # for reproducibility
def evaluation_model_MLSIM(pos):
    X_train, X_test, Y_train, Y_test  = train_test_split(data[pos][0],targets[pos], test_size=0.2,random_state=0)    
    digitized = discretize_learning_traces(X_train)
    X_train_feats = binarized_features2(digitized,4)
    print("Model MLSIM pour: ",LS[pos])
    n = np.shape(X_train_feats)[0]
    m = np.shape(X_train_feats)[1]
    print (n,m)
    print ("Nbr students:", n)
    print ("Learning traces dimension:",m)
    # construct DBN
    nhid_param2 = 17 #HYPERPARAMS.nb_hiden_node2 #nobre de noeuds de la deuxime couche cachée
    nhid_param1 = 12 #HYPERPARAMS.nb_hiden_node1 #nobre de noeuds de la premiere couche cachée
    #dbn = MDBN(input_data=X_train_feats, label=Y_train, input_size=m, hidden_layer_sizes=[nhid_param1, nhid_param2], output_size=1, batch_size=Training.batch_size, learning_rate=HYPERPARAMS.learning_rate,epochs=Training.epochs, C=HYPERPARAMS.C)
    dbn = MDBN(input_data=X_train_feats, label=Y_train, input_size=m, hidden_layer_sizes=[nhid_param1, nhid_param2], output_size=1, batch_size=50, learning_rate=0.39,epochs=700, C=1.0)    
    start = time.time()
    # pre-training (TrainUnsupervisedDBN)
    print ("Training the Hybrid Deep Belief Net model \n................")
    dbn.train(X_train_feats)
    print ("Unsupervised training time: ",(time.time()-start)," seconds")
    # fine-tuning (DBNSupervisedFineTuning)
    synthetic_V_list, h_list = dbn.predict(X_train_feats)
    #finetune training the last layer
    dbn.finetune(X_train_feats,Y_train,"Train data",bytraining=True)
    digitized_test = discretize_learning_traces(X_test)
    X_test_feats = binarized_features2(digitized_test,4)
    accuracy = dbn.evaluate(X_test_feats,Y_test,"Test data",verbose=True)

# %%
evaluation_model_MLSIM(0)
# Out:
# bins  [0, 1, 2, 3]  digitized 2  [[4 4 4 4]
#  [4 4 3 4]]  mat abs  [[11  8  8  9]
#  [ 4 10  2 35]]
# Model MLSIM pour:  Processing
# 405 16
# Nbr students: 405
# Learning traces dimension: 16
# Initialize weigths [[-2.97469156e-02 -4.26645035e-02 -2.77341851e-02 -5.08538910e-03
#   -2.23749324e-02  2.29910257e-03 -2.97571343e-02  5.95106606e-02
#    2.91018191e-02 -4.80907217e-02 -1.42156164e-02  1.60626474e-02
#   -4.68677592e-02  6.04435756e-02 -7.09689142e-03  3.61947928e-02]
#  [ 3.67648220e-02 -1.73423034e-02 -1.04870076e-02  1.05322660e-02
#    3.25214717e-02 -3.90239493e-02 -2.64791065e-02  2.12773573e-02
#   -4.39673285e-05 -4.01789154e-02 -1.08573373e-02 -3.76005956e-02
#    3.96242545e-03  4.15463379e-02 -3.93436319e-02  5.71699030e-02]
#  [-9.32316686e-03  5.00879895e-04  1.30886835e-03 -6.05260685e-02
#    2.89612586e-02  6.16631300e-02 -4.21403083e-02 -4.66706525e-02
#   -1.56457269e-02  2.41524305e-02 -6.21373712e-02 -1.63463672e-02
#   -5.51650843e-02  3.61670106e-02 -1.87788484e-02  2.53154650e-02]
#  [-1.09636534e-03  5.91090412e-02  4.19959850e-02  1.37796665e-02
#    8.06487243e-03  6.21736429e-02 -3.06594829e-02 -6.07027679e-02
#   -5.13693666e-02  5.48728251e-02  5.91824249e-02 -1.06480877e-03
#   -1.98830035e-02  2.78572022e-02 -6.11379047e-02  3.24941472e-02]
#  [ 2.14253483e-02 -3.86943093e-02  2.08080816e-02  5.13903002e-02
#   -4.22353218e-02  5.13222895e-02 -2.19552621e-02  2.50373025e-02
#   -2.93187077e-02  2.36983130e-03 -4.03165019e-02 -4.01925346e-03
#   -6.37943514e-03 -1.29919230e-02  3.64906792e-02 -8.25219402e-04]
#  [ 2.79934872e-02  3.66278791e-02 -1.85594875e-02  5.12066906e-02
#    2.66109375e-02  4.96559539e-02 -9.97395888e-03 -4.06048758e-03
#    5.04908999e-02  1.66935757e-02  4.10368295e-03 -3.28111544e-02
#    5.58129899e-02  7.42876543e-03  3.21689411e-02 -3.29813489e-02]
#  [-8.78015870e-03 -1.32358000e-02  1.33867450e-03 -4.68246255e-02
#    2.29566382e-02 -5.90387856e-02 -3.32696347e-02  2.95552495e-02
#    5.42762255e-02  1.42004882e-02 -1.15652211e-02  4.42395359e-02
#    6.16039742e-02 -2.55787245e-02 -1.37290612e-02  2.48695987e-02]
#  [-1.78725652e-02 -5.85093625e-02 -1.88573008e-02 -1.90514401e-03
#   -5.64706127e-02  5.18781756e-02  2.81958277e-02  3.40576825e-02
#   -5.04437518e-02 -5.78462661e-02 -3.00234218e-02 -4.68115322e-02
#   -3.27313148e-02  2.27717104e-02 -2.34767112e-03  5.45635488e-02]
#  [ 1.01748288e-02 -3.92365699e-02 -3.91339744e-02 -2.01807972e-02
#   -8.40409173e-03 -5.29037134e-02  1.70010860e-02 -5.51988068e-02
#    2.79599795e-02  2.00127487e-02 -6.13976784e-02  3.28976725e-02
#   -2.01710037e-02  3.45265964e-02 -2.05254417e-02  1.00677658e-02]
#  [-4.10028823e-02  4.32772095e-02 -2.86371237e-02  3.05799030e-02
#    7.92746024e-03  5.00109865e-02  6.04026038e-03 -5.93573304e-02
#   -5.24200410e-02  5.69448719e-02 -5.49605691e-03 -4.40815984e-02
#    2.18701257e-02  1.54583337e-02  6.27577668e-03  5.07187952e-02]
#  [ 4.97898653e-02 -2.96996934e-02  2.73945991e-02 -1.85668866e-03
#   -2.73893954e-02 -5.52150724e-02 -3.68676889e-02  1.75048849e-02
#   -2.67532078e-02 -7.18271177e-03 -1.92567908e-02 -3.28617522e-05
#    1.93840186e-02  5.61768647e-02 -5.83657189e-02  7.04237698e-03]
#  [ 1.76000216e-02 -4.26948748e-02  2.83059486e-02 -1.51849877e-02
#    1.44415207e-03  9.78013285e-03  4.31600963e-02  2.52286325e-02
#    1.61487112e-02 -5.60821179e-02 -5.67612555e-02  3.62688049e-03
#    3.53803490e-02  2.53847332e-02 -3.79226413e-02 -2.85319478e-02]]
# Initialize weigths [[-0.03247426  0.0777787  -0.02523344 -0.03038182 -0.02062823 -0.08090155
#   -0.07164228 -0.05231263 -0.07098385 -0.0072198   0.05467787 -0.06536868]
#  [-0.04488846 -0.0143075   0.01526858  0.04733284 -0.05163952 -0.05098896
#    0.00472241  0.00026534 -0.02058008 -0.02829959  0.0704767   0.07300888]
#  [ 0.01094017  0.01842974  0.01527159 -0.00947406 -0.03378191  0.058816
#   -0.01164462  0.05730879  0.08070766  0.0302759   0.03266766 -0.01027943]
#  [ 0.07080916  0.07345697 -0.01195025 -0.06155727 -0.04607873 -0.01533411
#   -0.07474153 -0.01573291  0.03534824 -0.01368836 -0.02721305  0.03467836]
#  [-0.05840067 -0.07702683 -0.0306936  -0.0807093  -0.01835476  0.03759542
#    0.00789454  0.01773235  0.06778057  0.03379388 -0.04378681  0.03232857]
#  [-0.03059106  0.00985271 -0.07552028 -0.02449077  0.02735352  0.07732121
#    0.07791676  0.00386554  0.00178928 -0.03439682  0.05722794 -0.02394466]
#  [ 0.03413643 -0.01941783  0.080005   -0.00127031  0.02907926  0.08147996
#    0.04264104  0.03276986 -0.01574699 -0.04866931 -0.02123514  0.06579246]
#  [-0.0604009  -0.03492021 -0.00409449  0.0133653   0.03346727 -0.02598356
#   -0.00655902  0.07460023 -0.05881901  0.01360688  0.00242389 -0.07484902]
#  [-0.00609218 -0.02275132 -0.01391283  0.03902245  0.06658551 -0.03596778
#    0.0734595  -0.04927178  0.0730743  -0.07797367 -0.06779385 -0.03906005]
#  [-0.07399146 -0.00516047 -0.00544381 -0.03467286  0.04762936 -0.08305249
#   -0.03033492  0.07506914 -0.0217731  -0.08289251  0.02369104 -0.02144554]
#  [-0.00209286 -0.02214517  0.02969605 -0.06573111  0.07040156 -0.04024183
#    0.02321329 -0.07944488 -0.01263403 -0.01105607  0.03600239 -0.05028733]
#  [ 0.08209746 -0.07183302 -0.05288107 -0.03225933  0.07037571  0.05846126
#   -0.05134841 -0.01414042  0.01171835 -0.05930904 -0.0336435  -0.07612863]
#  [ 0.03233419  0.07475379 -0.05223331  0.05463203 -0.07813092  0.05870255
#    0.07470393  0.03524145  0.03039309 -0.04217986  0.03730753 -0.03865874]
#  [-0.0141235  -0.00464367  0.00837783 -0.00668043 -0.08009024 -0.06468449
#    0.03229633 -0.05837257  0.00517524  0.00199695  0.04618617 -0.04199145]
#  [ 0.07251453 -0.04065389 -0.04300679 -0.0192222  -0.0523301   0.08293994
#   -0.00340972  0.04158302  0.06484591  0.06048317  0.02672308 -0.06453548]]
# Training the Hybrid Deep Belief Net model
# ................
# >> Epoch 1 finished 	RBM 1 Reconstruction error 5.349125
# >> Epoch 2 finished 	RBM 1 Reconstruction error 4.655487
# >> Epoch 3 finished 	RBM 1 Reconstruction error 4.476887
# >> Epoch 4 finished 	RBM 1 Reconstruction error 4.404371
# >> Epoch 5 finished 	RBM 1 Reconstruction error 4.373259
# >> Epoch 6 finished 	RBM 1 Reconstruction error 4.355735
# >> Epoch 7 finished 	RBM 1 Reconstruction error 4.352393
# >> Epoch 8 finished 	RBM 1 Reconstruction error 4.334260
# >> Epoch 9 finished 	RBM 1 Reconstruction error 4.331424
# >> Epoch 10 finished 	RBM 1 Reconstruction error 4.328206
# >> Epoch 11 finished 	RBM 1 Reconstruction error 4.325512
# >> Epoch 12 finished 	RBM 1 Reconstruction error 4.324129
# >> Epoch 13 finished 	RBM 1 Reconstruction error 4.320723
# >> Epoch 14 finished 	RBM 1 Reconstruction error 4.317930
# >> Epoch 15 finished 	RBM 1 Reconstruction error 4.309938
# >> Epoch 16 finished 	RBM 1 Reconstruction error 4.325579
# >> Epoch 17 finished 	RBM 1 Reconstruction error 4.305112
# >> Epoch 18 finished 	RBM 1 Reconstruction error 4.301626
# >> Epoch 19 finished 	RBM 1 Reconstruction error 4.302520
# >> Epoch 20 finished 	RBM 1 Reconstruction error 4.301893
# >> Epoch 21 finished 	RBM 1 Reconstruction error 4.301297
# >> Epoch 22 finished 	RBM 1 Reconstruction error 4.290880
# >> Epoch 23 finished 	RBM 1 Reconstruction error 4.290100
# >> Epoch 24 finished 	RBM 1 Reconstruction error 4.286628
# >> Epoch 25 finished 	RBM 1 Reconstruction error 4.288697
# >> Epoch 26 finished 	RBM 1 Reconstruction error 4.295146
# >> Epoch 27 finished 	RBM 1 Reconstruction error 4.284628
# >> Epoch 28 finished 	RBM 1 Reconstruction error 4.282686
# >> Epoch 29 finished 	RBM 1 Reconstruction error 4.286538
# >> Epoch 30 finished 	RBM 1 Reconstruction error 4.280875
# >> Epoch 31 finished 	RBM 1 Reconstruction error 4.272325
# >> Epoch 32 finished 	RBM 1 Reconstruction error 4.276887
# >> Epoch 33 finished 	RBM 1 Reconstruction error 4.267076
# >> Epoch 34 finished 	RBM 1 Reconstruction error 4.277488
# >> Epoch 35 finished 	RBM 1 Reconstruction error 4.258471
# >> Epoch 36 finished 	RBM 1 Reconstruction error 4.269389
# >> Epoch 37 finished 	RBM 1 Reconstruction error 4.257549
# >> Epoch 38 finished 	RBM 1 Reconstruction error 4.254087
# >> Epoch 39 finished 	RBM 1 Reconstruction error 4.252861
# >> Epoch 40 finished 	RBM 1 Reconstruction error 4.248673
# >> Epoch 41 finished 	RBM 1 Reconstruction error 4.244966
# >> Epoch 42 finished 	RBM 1 Reconstruction error 4.243503
# >> Epoch 43 finished 	RBM 1 Reconstruction error 4.246399
# >> Epoch 44 finished 	RBM 1 Reconstruction error 4.235157
# >> Epoch 45 finished 	RBM 1 Reconstruction error 4.238062
# >> Epoch 46 finished 	RBM 1 Reconstruction error 4.236617
# >> Epoch 47 finished 	RBM 1 Reconstruction error 4.224419
# >> Epoch 48 finished 	RBM 1 Reconstruction error 4.222609
# >> Epoch 49 finished 	RBM 1 Reconstruction error 4.216808
# >> Epoch 50 finished 	RBM 1 Reconstruction error 4.220039
# >> Epoch 51 finished 	RBM 1 Reconstruction error 4.211371
# >> Epoch 52 finished 	RBM 1 Reconstruction error 4.209164
# >> Epoch 53 finished 	RBM 1 Reconstruction error 4.215766
# >> Epoch 54 finished 	RBM 1 Reconstruction error 4.211979
# >> Epoch 55 finished 	RBM 1 Reconstruction error 4.203778
# >> Epoch 56 finished 	RBM 1 Reconstruction error 4.198332
# >> Epoch 57 finished 	RBM 1 Reconstruction error 4.197725
# >> Epoch 58 finished 	RBM 1 Reconstruction error 4.190465
# >> Epoch 59 finished 	RBM 1 Reconstruction error 4.195711
# >> Epoch 60 finished 	RBM 1 Reconstruction error 4.177775
# >> Epoch 61 finished 	RBM 1 Reconstruction error 4.175726
# >> Epoch 62 finished 	RBM 1 Reconstruction error 4.166161
# >> Epoch 63 finished 	RBM 1 Reconstruction error 4.169162
# >> Epoch 64 finished 	RBM 1 Reconstruction error 4.160183
# >> Epoch 65 finished 	RBM 1 Reconstruction error 4.151863
# >> Epoch 66 finished 	RBM 1 Reconstruction error 4.150467
# >> Epoch 67 finished 	RBM 1 Reconstruction error 4.144667
# >> Epoch 68 finished 	RBM 1 Reconstruction error 4.133818
# >> Epoch 69 finished 	RBM 1 Reconstruction error 4.128361
# >> Epoch 70 finished 	RBM 1 Reconstruction error 4.126050
# >> Epoch 71 finished 	RBM 1 Reconstruction error 4.140015
# >> Epoch 72 finished 	RBM 1 Reconstruction error 4.110915
# >> Epoch 73 finished 	RBM 1 Reconstruction error 4.106626
# >> Epoch 74 finished 	RBM 1 Reconstruction error 4.092687
# >> Epoch 75 finished 	RBM 1 Reconstruction error 4.085936
# >> Epoch 76 finished 	RBM 1 Reconstruction error 4.077529
# >> Epoch 77 finished 	RBM 1 Reconstruction error 4.076196
# >> Epoch 78 finished 	RBM 1 Reconstruction error 4.067941
# >> Epoch 79 finished 	RBM 1 Reconstruction error 4.055518
# >> Epoch 80 finished 	RBM 1 Reconstruction error 4.043106
# >> Epoch 81 finished 	RBM 1 Reconstruction error 4.031793
# >> Epoch 82 finished 	RBM 1 Reconstruction error 4.022154
# >> Epoch 83 finished 	RBM 1 Reconstruction error 4.010633
# >> Epoch 84 finished 	RBM 1 Reconstruction error 3.996404
# >> Epoch 85 finished 	RBM 1 Reconstruction error 3.985112
# >> Epoch 86 finished 	RBM 1 Reconstruction error 3.974441
# >> Epoch 87 finished 	RBM 1 Reconstruction error 3.959799
# >> Epoch 88 finished 	RBM 1 Reconstruction error 3.941143
# >> Epoch 89 finished 	RBM 1 Reconstruction error 3.930048
# >> Epoch 90 finished 	RBM 1 Reconstruction error 3.919932
# >> Epoch 91 finished 	RBM 1 Reconstruction error 3.899582
# >> Epoch 92 finished 	RBM 1 Reconstruction error 3.889692
# >> Epoch 93 finished 	RBM 1 Reconstruction error 3.861969
# >> Epoch 94 finished 	RBM 1 Reconstruction error 3.838266
# >> Epoch 95 finished 	RBM 1 Reconstruction error 3.820108
# >> Epoch 96 finished 	RBM 1 Reconstruction error 3.800204
# >> Epoch 97 finished 	RBM 1 Reconstruction error 3.779982
# >> Epoch 98 finished 	RBM 1 Reconstruction error 3.777051
# >> Epoch 99 finished 	RBM 1 Reconstruction error 3.745019
# >> Epoch 100 finished 	RBM 1 Reconstruction error 3.726967
# >> Epoch 101 finished 	RBM 1 Reconstruction error 3.709822
# >> Epoch 102 finished 	RBM 1 Reconstruction error 3.684215
# >> Epoch 103 finished 	RBM 1 Reconstruction error 3.659476
# >> Epoch 104 finished 	RBM 1 Reconstruction error 3.642778
# >> Epoch 105 finished 	RBM 1 Reconstruction error 3.613033
# >> Epoch 106 finished 	RBM 1 Reconstruction error 3.589519
# >> Epoch 107 finished 	RBM 1 Reconstruction error 3.570415
# >> Epoch 108 finished 	RBM 1 Reconstruction error 3.553440
# >> Epoch 109 finished 	RBM 1 Reconstruction error 3.533458
# >> Epoch 110 finished 	RBM 1 Reconstruction error 3.503402
# >> Epoch 111 finished 	RBM 1 Reconstruction error 3.476364
# >> Epoch 112 finished 	RBM 1 Reconstruction error 3.451049
# >> Epoch 113 finished 	RBM 1 Reconstruction error 3.428028
# >> Epoch 114 finished 	RBM 1 Reconstruction error 3.414196
# >> Epoch 115 finished 	RBM 1 Reconstruction error 3.379172
# >> Epoch 116 finished 	RBM 1 Reconstruction error 3.356731
# >> Epoch 117 finished 	RBM 1 Reconstruction error 3.340533
# >> Epoch 118 finished 	RBM 1 Reconstruction error 3.316831
# >> Epoch 119 finished 	RBM 1 Reconstruction error 3.296129
# >> Epoch 120 finished 	RBM 1 Reconstruction error 3.283079
# >> Epoch 121 finished 	RBM 1 Reconstruction error 3.261686
# >> Epoch 122 finished 	RBM 1 Reconstruction error 3.235066
# >> Epoch 123 finished 	RBM 1 Reconstruction error 3.215472
# >> Epoch 124 finished 	RBM 1 Reconstruction error 3.190697
# >> Epoch 125 finished 	RBM 1 Reconstruction error 3.175986
# >> Epoch 126 finished 	RBM 1 Reconstruction error 3.154921
# >> Epoch 127 finished 	RBM 1 Reconstruction error 3.148951
# >> Epoch 128 finished 	RBM 1 Reconstruction error 3.124788
# >> Epoch 129 finished 	RBM 1 Reconstruction error 3.119988
# >> Epoch 130 finished 	RBM 1 Reconstruction error 3.111920
# >> Epoch 131 finished 	RBM 1 Reconstruction error 3.077095
# >> Epoch 132 finished 	RBM 1 Reconstruction error 3.069126
# >> Epoch 133 finished 	RBM 1 Reconstruction error 3.048076
# >> Epoch 134 finished 	RBM 1 Reconstruction error 3.035319
# >> Epoch 135 finished 	RBM 1 Reconstruction error 3.029280
# >> Epoch 136 finished 	RBM 1 Reconstruction error 3.010089
# >> Epoch 137 finished 	RBM 1 Reconstruction error 2.991996
# >> Epoch 138 finished 	RBM 1 Reconstruction error 2.985482
# >> Epoch 139 finished 	RBM 1 Reconstruction error 2.969369
# >> Epoch 140 finished 	RBM 1 Reconstruction error 2.957469
# >> Epoch 141 finished 	RBM 1 Reconstruction error 2.950170
# >> Epoch 142 finished 	RBM 1 Reconstruction error 2.931077
# >> Epoch 143 finished 	RBM 1 Reconstruction error 2.921710
# >> Epoch 144 finished 	RBM 1 Reconstruction error 2.927544
# >> Epoch 145 finished 	RBM 1 Reconstruction error 2.901440
# >> Epoch 146 finished 	RBM 1 Reconstruction error 2.882490
# >> Epoch 147 finished 	RBM 1 Reconstruction error 2.866710
# >> Epoch 148 finished 	RBM 1 Reconstruction error 2.855674
# >> Epoch 149 finished 	RBM 1 Reconstruction error 2.847499
# >> Epoch 150 finished 	RBM 1 Reconstruction error 2.838251
# >> Epoch 151 finished 	RBM 1 Reconstruction error 2.815353
# >> Epoch 152 finished 	RBM 1 Reconstruction error 2.808882
# >> Epoch 153 finished 	RBM 1 Reconstruction error 2.798336
# >> Epoch 154 finished 	RBM 1 Reconstruction error 2.795512
# >> Epoch 155 finished 	RBM 1 Reconstruction error 2.777891
# >> Epoch 156 finished 	RBM 1 Reconstruction error 2.755387
# >> Epoch 157 finished 	RBM 1 Reconstruction error 2.743782
# >> Epoch 158 finished 	RBM 1 Reconstruction error 2.736893
# >> Epoch 159 finished 	RBM 1 Reconstruction error 2.734627
# >> Epoch 160 finished 	RBM 1 Reconstruction error 2.714542
# >> Epoch 161 finished 	RBM 1 Reconstruction error 2.705276
# >> Epoch 162 finished 	RBM 1 Reconstruction error 2.698969
# >> Epoch 163 finished 	RBM 1 Reconstruction error 2.669140
# >> Epoch 164 finished 	RBM 1 Reconstruction error 2.667877
# >> Epoch 165 finished 	RBM 1 Reconstruction error 2.656829
# >> Epoch 166 finished 	RBM 1 Reconstruction error 2.636135
# >> Epoch 167 finished 	RBM 1 Reconstruction error 2.633799
# >> Epoch 168 finished 	RBM 1 Reconstruction error 2.616191
# >> Epoch 169 finished 	RBM 1 Reconstruction error 2.604403
# >> Epoch 170 finished 	RBM 1 Reconstruction error 2.594682
# >> Epoch 171 finished 	RBM 1 Reconstruction error 2.581992
# >> Epoch 172 finished 	RBM 1 Reconstruction error 2.570952
# >> Epoch 173 finished 	RBM 1 Reconstruction error 2.557550
# >> Epoch 174 finished 	RBM 1 Reconstruction error 2.550647
# >> Epoch 175 finished 	RBM 1 Reconstruction error 2.544461
# >> Epoch 176 finished 	RBM 1 Reconstruction error 2.525492
# >> Epoch 177 finished 	RBM 1 Reconstruction error 2.511220
# >> Epoch 178 finished 	RBM 1 Reconstruction error 2.511673
# >> Epoch 179 finished 	RBM 1 Reconstruction error 2.487038
# >> Epoch 180 finished 	RBM 1 Reconstruction error 2.474361
# >> Epoch 181 finished 	RBM 1 Reconstruction error 2.470390
# >> Epoch 182 finished 	RBM 1 Reconstruction error 2.462898
# >> Epoch 183 finished 	RBM 1 Reconstruction error 2.461389
# >> Epoch 184 finished 	RBM 1 Reconstruction error 2.438300
# >> Epoch 185 finished 	RBM 1 Reconstruction error 2.425744
# >> Epoch 186 finished 	RBM 1 Reconstruction error 2.415459
# >> Epoch 187 finished 	RBM 1 Reconstruction error 2.411996
# >> Epoch 188 finished 	RBM 1 Reconstruction error 2.405619
# >> Epoch 189 finished 	RBM 1 Reconstruction error 2.388444
# >> Epoch 190 finished 	RBM 1 Reconstruction error 2.382175
# >> Epoch 191 finished 	RBM 1 Reconstruction error 2.376634
# >> Epoch 192 finished 	RBM 1 Reconstruction error 2.369837
# >> Epoch 193 finished 	RBM 1 Reconstruction error 2.349321
# >> Epoch 194 finished 	RBM 1 Reconstruction error 2.351642
# >> Epoch 195 finished 	RBM 1 Reconstruction error 2.356093
# >> Epoch 196 finished 	RBM 1 Reconstruction error 2.343306
# >> Epoch 197 finished 	RBM 1 Reconstruction error 2.327518
# >> Epoch 198 finished 	RBM 1 Reconstruction error 2.306367
# >> Epoch 199 finished 	RBM 1 Reconstruction error 2.300856
# >> Epoch 200 finished 	RBM 1 Reconstruction error 2.281593
# >> Epoch 201 finished 	RBM 1 Reconstruction error 2.281426
# >> Epoch 202 finished 	RBM 1 Reconstruction error 2.276393
# >> Epoch 203 finished 	RBM 1 Reconstruction error 2.271176
# >> Epoch 204 finished 	RBM 1 Reconstruction error 2.257628
# >> Epoch 205 finished 	RBM 1 Reconstruction error 2.248955
# >> Epoch 206 finished 	RBM 1 Reconstruction error 2.245570
# >> Epoch 207 finished 	RBM 1 Reconstruction error 2.235806
# >> Epoch 208 finished 	RBM 1 Reconstruction error 2.224965
# >> Epoch 209 finished 	RBM 1 Reconstruction error 2.220739
# >> Epoch 210 finished 	RBM 1 Reconstruction error 2.205382
# >> Epoch 211 finished 	RBM 1 Reconstruction error 2.203937
# >> Epoch 212 finished 	RBM 1 Reconstruction error 2.195603
# >> Epoch 213 finished 	RBM 1 Reconstruction error 2.178069
# >> Epoch 214 finished 	RBM 1 Reconstruction error 2.166049
# >> Epoch 215 finished 	RBM 1 Reconstruction error 2.160102
# >> Epoch 216 finished 	RBM 1 Reconstruction error 2.152511
# >> Epoch 217 finished 	RBM 1 Reconstruction error 2.146134
# >> Epoch 218 finished 	RBM 1 Reconstruction error 2.154118
# >> Epoch 219 finished 	RBM 1 Reconstruction error 2.140803
# >> Epoch 220 finished 	RBM 1 Reconstruction error 2.122179
# >> Epoch 221 finished 	RBM 1 Reconstruction error 2.112558
# >> Epoch 222 finished 	RBM 1 Reconstruction error 2.111935
# >> Epoch 223 finished 	RBM 1 Reconstruction error 2.110085
# >> Epoch 224 finished 	RBM 1 Reconstruction error 2.095814
# >> Epoch 225 finished 	RBM 1 Reconstruction error 2.087990
# >> Epoch 226 finished 	RBM 1 Reconstruction error 2.088646
# >> Epoch 227 finished 	RBM 1 Reconstruction error 2.078986
# >> Epoch 228 finished 	RBM 1 Reconstruction error 2.072422
# >> Epoch 229 finished 	RBM 1 Reconstruction error 2.068592
# >> Epoch 230 finished 	RBM 1 Reconstruction error 2.057859
# >> Epoch 231 finished 	RBM 1 Reconstruction error 2.046975
# >> Epoch 232 finished 	RBM 1 Reconstruction error 2.048609
# >> Epoch 233 finished 	RBM 1 Reconstruction error 2.037740
# >> Epoch 234 finished 	RBM 1 Reconstruction error 2.039507
# >> Epoch 235 finished 	RBM 1 Reconstruction error 2.028616
# >> Epoch 236 finished 	RBM 1 Reconstruction error 2.014395
# >> Epoch 237 finished 	RBM 1 Reconstruction error 2.018919
# >> Epoch 238 finished 	RBM 1 Reconstruction error 2.015077
# >> Epoch 239 finished 	RBM 1 Reconstruction error 2.002178
# >> Epoch 240 finished 	RBM 1 Reconstruction error 1.992529
# >> Epoch 241 finished 	RBM 1 Reconstruction error 1.980180
# >> Epoch 242 finished 	RBM 1 Reconstruction error 1.967649
# >> Epoch 243 finished 	RBM 1 Reconstruction error 1.959025
# >> Epoch 244 finished 	RBM 1 Reconstruction error 1.954058
# >> Epoch 245 finished 	RBM 1 Reconstruction error 1.950753
# >> Epoch 246 finished 	RBM 1 Reconstruction error 1.951193
# >> Epoch 247 finished 	RBM 1 Reconstruction error 1.948216
# >> Epoch 248 finished 	RBM 1 Reconstruction error 1.938515
# >> Epoch 249 finished 	RBM 1 Reconstruction error 1.926880
# >> Epoch 250 finished 	RBM 1 Reconstruction error 1.916351
# >> Epoch 251 finished 	RBM 1 Reconstruction error 1.909798
# >> Epoch 252 finished 	RBM 1 Reconstruction error 1.901844
# >> Epoch 253 finished 	RBM 1 Reconstruction error 1.894988
# >> Epoch 254 finished 	RBM 1 Reconstruction error 1.890763
# >> Epoch 255 finished 	RBM 1 Reconstruction error 1.882732
# >> Epoch 256 finished 	RBM 1 Reconstruction error 1.870641
# >> Epoch 257 finished 	RBM 1 Reconstruction error 1.866314
# >> Epoch 258 finished 	RBM 1 Reconstruction error 1.850021
# >> Epoch 259 finished 	RBM 1 Reconstruction error 1.850495
# >> Epoch 260 finished 	RBM 1 Reconstruction error 1.842671
# >> Epoch 261 finished 	RBM 1 Reconstruction error 1.831035
# >> Epoch 262 finished 	RBM 1 Reconstruction error 1.831310
# >> Epoch 263 finished 	RBM 1 Reconstruction error 1.833308
# >> Epoch 264 finished 	RBM 1 Reconstruction error 1.812965
# >> Epoch 265 finished 	RBM 1 Reconstruction error 1.816846
# >> Epoch 266 finished 	RBM 1 Reconstruction error 1.802503
# >> Epoch 267 finished 	RBM 1 Reconstruction error 1.796007
# >> Epoch 268 finished 	RBM 1 Reconstruction error 1.788948
# >> Epoch 269 finished 	RBM 1 Reconstruction error 1.780193
# >> Epoch 270 finished 	RBM 1 Reconstruction error 1.771805
# >> Epoch 271 finished 	RBM 1 Reconstruction error 1.773578
# >> Epoch 272 finished 	RBM 1 Reconstruction error 1.767492
# >> Epoch 273 finished 	RBM 1 Reconstruction error 1.757393
# >> Epoch 274 finished 	RBM 1 Reconstruction error 1.751328
# >> Epoch 275 finished 	RBM 1 Reconstruction error 1.733986
# >> Epoch 276 finished 	RBM 1 Reconstruction error 1.740130
# >> Epoch 277 finished 	RBM 1 Reconstruction error 1.724638
# >> Epoch 278 finished 	RBM 1 Reconstruction error 1.720188
# >> Epoch 279 finished 	RBM 1 Reconstruction error 1.714343
# >> Epoch 280 finished 	RBM 1 Reconstruction error 1.703870
# >> Epoch 281 finished 	RBM 1 Reconstruction error 1.695043
# >> Epoch 282 finished 	RBM 1 Reconstruction error 1.678223
# >> Epoch 283 finished 	RBM 1 Reconstruction error 1.688616
# >> Epoch 284 finished 	RBM 1 Reconstruction error 1.676723
# >> Epoch 285 finished 	RBM 1 Reconstruction error 1.664634
# >> Epoch 286 finished 	RBM 1 Reconstruction error 1.660445
# >> Epoch 287 finished 	RBM 1 Reconstruction error 1.653321
# >> Epoch 288 finished 	RBM 1 Reconstruction error 1.643189
# >> Epoch 289 finished 	RBM 1 Reconstruction error 1.631190
# >> Epoch 290 finished 	RBM 1 Reconstruction error 1.622804
# >> Epoch 291 finished 	RBM 1 Reconstruction error 1.626483
# >> Epoch 292 finished 	RBM 1 Reconstruction error 1.627574
# >> Epoch 293 finished 	RBM 1 Reconstruction error 1.609271
# >> Epoch 294 finished 	RBM 1 Reconstruction error 1.598510
# >> Epoch 295 finished 	RBM 1 Reconstruction error 1.596655
# >> Epoch 296 finished 	RBM 1 Reconstruction error 1.590449
# >> Epoch 297 finished 	RBM 1 Reconstruction error 1.579979
# >> Epoch 298 finished 	RBM 1 Reconstruction error 1.580542
# >> Epoch 299 finished 	RBM 1 Reconstruction error 1.556952
# >> Epoch 300 finished 	RBM 1 Reconstruction error 1.551753
# >> Epoch 301 finished 	RBM 1 Reconstruction error 1.542192
# >> Epoch 302 finished 	RBM 1 Reconstruction error 1.545266
# >> Epoch 303 finished 	RBM 1 Reconstruction error 1.525899
# >> Epoch 304 finished 	RBM 1 Reconstruction error 1.529328
# >> Epoch 305 finished 	RBM 1 Reconstruction error 1.525473
# >> Epoch 306 finished 	RBM 1 Reconstruction error 1.516570
# >> Epoch 307 finished 	RBM 1 Reconstruction error 1.499402
# >> Epoch 308 finished 	RBM 1 Reconstruction error 1.500483
# >> Epoch 309 finished 	RBM 1 Reconstruction error 1.500177
# >> Epoch 310 finished 	RBM 1 Reconstruction error 1.485186
# >> Epoch 311 finished 	RBM 1 Reconstruction error 1.474755
# >> Epoch 312 finished 	RBM 1 Reconstruction error 1.464300
# >> Epoch 313 finished 	RBM 1 Reconstruction error 1.454092
# >> Epoch 314 finished 	RBM 1 Reconstruction error 1.447881
# >> Epoch 315 finished 	RBM 1 Reconstruction error 1.449064
# >> Epoch 316 finished 	RBM 1 Reconstruction error 1.448731
# >> Epoch 317 finished 	RBM 1 Reconstruction error 1.429260
# >> Epoch 318 finished 	RBM 1 Reconstruction error 1.427959
# >> Epoch 319 finished 	RBM 1 Reconstruction error 1.415580
# >> Epoch 320 finished 	RBM 1 Reconstruction error 1.402890
# >> Epoch 321 finished 	RBM 1 Reconstruction error 1.399896
# >> Epoch 322 finished 	RBM 1 Reconstruction error 1.387924
# >> Epoch 323 finished 	RBM 1 Reconstruction error 1.383995
# >> Epoch 324 finished 	RBM 1 Reconstruction error 1.369795
# >> Epoch 325 finished 	RBM 1 Reconstruction error 1.366323
# >> Epoch 326 finished 	RBM 1 Reconstruction error 1.356484
# >> Epoch 327 finished 	RBM 1 Reconstruction error 1.353662
# >> Epoch 328 finished 	RBM 1 Reconstruction error 1.340683
# >> Epoch 329 finished 	RBM 1 Reconstruction error 1.334416
# >> Epoch 330 finished 	RBM 1 Reconstruction error 1.337037
# >> Epoch 331 finished 	RBM 1 Reconstruction error 1.332149
# >> Epoch 332 finished 	RBM 1 Reconstruction error 1.327086
# >> Epoch 333 finished 	RBM 1 Reconstruction error 1.315266
# >> Epoch 334 finished 	RBM 1 Reconstruction error 1.306541
# >> Epoch 335 finished 	RBM 1 Reconstruction error 1.297708
# >> Epoch 336 finished 	RBM 1 Reconstruction error 1.290478
# >> Epoch 337 finished 	RBM 1 Reconstruction error 1.278638
# >> Epoch 338 finished 	RBM 1 Reconstruction error 1.276877
# >> Epoch 339 finished 	RBM 1 Reconstruction error 1.271999
# >> Epoch 340 finished 	RBM 1 Reconstruction error 1.265571
# >> Epoch 341 finished 	RBM 1 Reconstruction error 1.251952
# >> Epoch 342 finished 	RBM 1 Reconstruction error 1.247847
# >> Epoch 343 finished 	RBM 1 Reconstruction error 1.240433
# >> Epoch 344 finished 	RBM 1 Reconstruction error 1.240789
# >> Epoch 345 finished 	RBM 1 Reconstruction error 1.237803
# >> Epoch 346 finished 	RBM 1 Reconstruction error 1.228902
# >> Epoch 347 finished 	RBM 1 Reconstruction error 1.221596
# >> Epoch 348 finished 	RBM 1 Reconstruction error 1.218664
# >> Epoch 349 finished 	RBM 1 Reconstruction error 1.211839
# >> Epoch 350 finished 	RBM 1 Reconstruction error 1.203385
# >> Epoch 351 finished 	RBM 1 Reconstruction error 1.197125
# >> Epoch 352 finished 	RBM 1 Reconstruction error 1.188187
# >> Epoch 353 finished 	RBM 1 Reconstruction error 1.182473
# >> Epoch 354 finished 	RBM 1 Reconstruction error 1.182222
# >> Epoch 355 finished 	RBM 1 Reconstruction error 1.174267
# >> Epoch 356 finished 	RBM 1 Reconstruction error 1.170135
# >> Epoch 357 finished 	RBM 1 Reconstruction error 1.160360
# >> Epoch 358 finished 	RBM 1 Reconstruction error 1.152106
# >> Epoch 359 finished 	RBM 1 Reconstruction error 1.151593
# >> Epoch 360 finished 	RBM 1 Reconstruction error 1.142078
# >> Epoch 361 finished 	RBM 1 Reconstruction error 1.142737
# >> Epoch 362 finished 	RBM 1 Reconstruction error 1.142545
# >> Epoch 363 finished 	RBM 1 Reconstruction error 1.132480
# >> Epoch 364 finished 	RBM 1 Reconstruction error 1.122174
# >> Epoch 365 finished 	RBM 1 Reconstruction error 1.114145
# >> Epoch 366 finished 	RBM 1 Reconstruction error 1.104220
# >> Epoch 367 finished 	RBM 1 Reconstruction error 1.103424
# >> Epoch 368 finished 	RBM 1 Reconstruction error 1.097098
# >> Epoch 369 finished 	RBM 1 Reconstruction error 1.091532
# >> Epoch 370 finished 	RBM 1 Reconstruction error 1.085160
# >> Epoch 371 finished 	RBM 1 Reconstruction error 1.081143
# >> Epoch 372 finished 	RBM 1 Reconstruction error 1.081004
# >> Epoch 373 finished 	RBM 1 Reconstruction error 1.079622
# >> Epoch 374 finished 	RBM 1 Reconstruction error 1.077210
# >> Epoch 375 finished 	RBM 1 Reconstruction error 1.073782
# >> Epoch 376 finished 	RBM 1 Reconstruction error 1.070779
# >> Epoch 377 finished 	RBM 1 Reconstruction error 1.058970
# >> Epoch 378 finished 	RBM 1 Reconstruction error 1.049987
# >> Epoch 379 finished 	RBM 1 Reconstruction error 1.051913
# >> Epoch 380 finished 	RBM 1 Reconstruction error 1.042407
# >> Epoch 381 finished 	RBM 1 Reconstruction error 1.036850
# >> Epoch 382 finished 	RBM 1 Reconstruction error 1.035670
# >> Epoch 383 finished 	RBM 1 Reconstruction error 1.031044
# >> Epoch 384 finished 	RBM 1 Reconstruction error 1.028681
# >> Epoch 385 finished 	RBM 1 Reconstruction error 1.028492
# >> Epoch 386 finished 	RBM 1 Reconstruction error 1.018947
# >> Epoch 387 finished 	RBM 1 Reconstruction error 1.015601
# >> Epoch 388 finished 	RBM 1 Reconstruction error 1.009876
# >> Epoch 389 finished 	RBM 1 Reconstruction error 1.003987
# >> Epoch 390 finished 	RBM 1 Reconstruction error 0.998054
# >> Epoch 391 finished 	RBM 1 Reconstruction error 0.994073
# >> Epoch 392 finished 	RBM 1 Reconstruction error 0.995771
# >> Epoch 393 finished 	RBM 1 Reconstruction error 0.994845
# >> Epoch 394 finished 	RBM 1 Reconstruction error 0.990622
# >> Epoch 395 finished 	RBM 1 Reconstruction error 0.987219
# >> Epoch 396 finished 	RBM 1 Reconstruction error 0.984803
# >> Epoch 397 finished 	RBM 1 Reconstruction error 0.980579
# >> Epoch 398 finished 	RBM 1 Reconstruction error 0.974077
# >> Epoch 399 finished 	RBM 1 Reconstruction error 0.968884
# >> Epoch 400 finished 	RBM 1 Reconstruction error 0.968183
# >> Epoch 401 finished 	RBM 1 Reconstruction error 0.966355
# >> Epoch 402 finished 	RBM 1 Reconstruction error 0.959882
# >> Epoch 403 finished 	RBM 1 Reconstruction error 0.958622
# >> Epoch 404 finished 	RBM 1 Reconstruction error 0.956383
# >> Epoch 405 finished 	RBM 1 Reconstruction error 0.953930
# >> Epoch 406 finished 	RBM 1 Reconstruction error 0.950822
# >> Epoch 407 finished 	RBM 1 Reconstruction error 0.947426
# >> Epoch 408 finished 	RBM 1 Reconstruction error 0.942977
# >> Epoch 409 finished 	RBM 1 Reconstruction error 0.937747
# >> Epoch 410 finished 	RBM 1 Reconstruction error 0.936841
# >> Epoch 411 finished 	RBM 1 Reconstruction error 0.933292
# >> Epoch 412 finished 	RBM 1 Reconstruction error 0.928969
# >> Epoch 413 finished 	RBM 1 Reconstruction error 0.934115
# >> Epoch 414 finished 	RBM 1 Reconstruction error 0.929416
# >> Epoch 415 finished 	RBM 1 Reconstruction error 0.926717
# >> Epoch 416 finished 	RBM 1 Reconstruction error 0.921566
# >> Epoch 417 finished 	RBM 1 Reconstruction error 0.923016
# >> Epoch 418 finished 	RBM 1 Reconstruction error 0.920255
# >> Epoch 419 finished 	RBM 1 Reconstruction error 0.918241
# >> Epoch 420 finished 	RBM 1 Reconstruction error 0.912377
# >> Epoch 421 finished 	RBM 1 Reconstruction error 0.906551
# >> Epoch 422 finished 	RBM 1 Reconstruction error 0.907882
# >> Epoch 423 finished 	RBM 1 Reconstruction error 0.909853
# >> Epoch 424 finished 	RBM 1 Reconstruction error 0.903932
# >> Epoch 425 finished 	RBM 1 Reconstruction error 0.901739
# >> Epoch 426 finished 	RBM 1 Reconstruction error 0.897840
# >> Epoch 427 finished 	RBM 1 Reconstruction error 0.894278
# >> Epoch 428 finished 	RBM 1 Reconstruction error 0.891290
# >> Epoch 429 finished 	RBM 1 Reconstruction error 0.895095
# >> Epoch 430 finished 	RBM 1 Reconstruction error 0.891054
# >> Epoch 431 finished 	RBM 1 Reconstruction error 0.892377
# >> Epoch 432 finished 	RBM 1 Reconstruction error 0.889330
# >> Epoch 433 finished 	RBM 1 Reconstruction error 0.887266
# >> Epoch 434 finished 	RBM 1 Reconstruction error 0.884831
# >> Epoch 435 finished 	RBM 1 Reconstruction error 0.885820
# >> Epoch 436 finished 	RBM 1 Reconstruction error 0.880486
# >> Epoch 437 finished 	RBM 1 Reconstruction error 0.880701
# >> Epoch 438 finished 	RBM 1 Reconstruction error 0.880246
# >> Epoch 439 finished 	RBM 1 Reconstruction error 0.880072
# >> Epoch 440 finished 	RBM 1 Reconstruction error 0.873239
# >> Epoch 441 finished 	RBM 1 Reconstruction error 0.873554
# >> Epoch 442 finished 	RBM 1 Reconstruction error 0.876188
# >> Epoch 443 finished 	RBM 1 Reconstruction error 0.870148
# >> Epoch 444 finished 	RBM 1 Reconstruction error 0.867422
# >> Epoch 445 finished 	RBM 1 Reconstruction error 0.868304
# >> Epoch 446 finished 	RBM 1 Reconstruction error 0.869800
# >> Epoch 447 finished 	RBM 1 Reconstruction error 0.863333
# >> Epoch 448 finished 	RBM 1 Reconstruction error 0.860111
# >> Epoch 449 finished 	RBM 1 Reconstruction error 0.853870
# >> Epoch 450 finished 	RBM 1 Reconstruction error 0.852720
# >> Epoch 451 finished 	RBM 1 Reconstruction error 0.847988
# >> Epoch 452 finished 	RBM 1 Reconstruction error 0.848152
# >> Epoch 453 finished 	RBM 1 Reconstruction error 0.847424
# >> Epoch 454 finished 	RBM 1 Reconstruction error 0.848688
# >> Epoch 455 finished 	RBM 1 Reconstruction error 0.849247
# >> Epoch 456 finished 	RBM 1 Reconstruction error 0.845905
# >> Epoch 457 finished 	RBM 1 Reconstruction error 0.845397
# >> Epoch 458 finished 	RBM 1 Reconstruction error 0.845154
# >> Epoch 459 finished 	RBM 1 Reconstruction error 0.841682
# >> Epoch 460 finished 	RBM 1 Reconstruction error 0.839202
# >> Epoch 461 finished 	RBM 1 Reconstruction error 0.839832
# >> Epoch 462 finished 	RBM 1 Reconstruction error 0.836767
# >> Epoch 463 finished 	RBM 1 Reconstruction error 0.832290
# >> Epoch 464 finished 	RBM 1 Reconstruction error 0.829186
# >> Epoch 465 finished 	RBM 1 Reconstruction error 0.828275
# >> Epoch 466 finished 	RBM 1 Reconstruction error 0.825773
# >> Epoch 467 finished 	RBM 1 Reconstruction error 0.824423
# >> Epoch 468 finished 	RBM 1 Reconstruction error 0.821967
# >> Epoch 469 finished 	RBM 1 Reconstruction error 0.822716
# >> Epoch 470 finished 	RBM 1 Reconstruction error 0.823693
# >> Epoch 471 finished 	RBM 1 Reconstruction error 0.820172
# >> Epoch 472 finished 	RBM 1 Reconstruction error 0.818651
# >> Epoch 473 finished 	RBM 1 Reconstruction error 0.816785
# >> Epoch 474 finished 	RBM 1 Reconstruction error 0.815643
# >> Epoch 475 finished 	RBM 1 Reconstruction error 0.813934
# >> Epoch 476 finished 	RBM 1 Reconstruction error 0.813026
# >> Epoch 477 finished 	RBM 1 Reconstruction error 0.809124
# >> Epoch 478 finished 	RBM 1 Reconstruction error 0.807140
# >> Epoch 479 finished 	RBM 1 Reconstruction error 0.804952
# >> Epoch 480 finished 	RBM 1 Reconstruction error 0.803342
# >> Epoch 481 finished 	RBM 1 Reconstruction error 0.804063
# >> Epoch 482 finished 	RBM 1 Reconstruction error 0.800894
# >> Epoch 483 finished 	RBM 1 Reconstruction error 0.801132
# >> Epoch 484 finished 	RBM 1 Reconstruction error 0.803174
# >> Epoch 485 finished 	RBM 1 Reconstruction error 0.804381
# >> Epoch 486 finished 	RBM 1 Reconstruction error 0.805413
# >> Epoch 487 finished 	RBM 1 Reconstruction error 0.802761
# >> Epoch 488 finished 	RBM 1 Reconstruction error 0.800581
# >> Epoch 489 finished 	RBM 1 Reconstruction error 0.799082
# >> Epoch 490 finished 	RBM 1 Reconstruction error 0.794922
# >> Epoch 491 finished 	RBM 1 Reconstruction error 0.797438
# >> Epoch 492 finished 	RBM 1 Reconstruction error 0.796687
# >> Epoch 493 finished 	RBM 1 Reconstruction error 0.793336
# >> Epoch 494 finished 	RBM 1 Reconstruction error 0.793886
# >> Epoch 495 finished 	RBM 1 Reconstruction error 0.794547
# >> Epoch 496 finished 	RBM 1 Reconstruction error 0.793505
# >> Epoch 497 finished 	RBM 1 Reconstruction error 0.795686
# >> Epoch 498 finished 	RBM 1 Reconstruction error 0.787685
# >> Epoch 499 finished 	RBM 1 Reconstruction error 0.789231
# >> Epoch 500 finished 	RBM 1 Reconstruction error 0.790143
# >> Epoch 501 finished 	RBM 1 Reconstruction error 0.780449
# >> Epoch 502 finished 	RBM 1 Reconstruction error 0.781800
# >> Epoch 503 finished 	RBM 1 Reconstruction error 0.785669
# >> Epoch 504 finished 	RBM 1 Reconstruction error 0.783607
# >> Epoch 505 finished 	RBM 1 Reconstruction error 0.780805
# >> Epoch 506 finished 	RBM 1 Reconstruction error 0.778438
# >> Epoch 507 finished 	RBM 1 Reconstruction error 0.778540
# >> Epoch 508 finished 	RBM 1 Reconstruction error 0.778026
# >> Epoch 509 finished 	RBM 1 Reconstruction error 0.778168
# >> Epoch 510 finished 	RBM 1 Reconstruction error 0.773469
# >> Epoch 511 finished 	RBM 1 Reconstruction error 0.770285
# >> Epoch 512 finished 	RBM 1 Reconstruction error 0.765523
# >> Epoch 513 finished 	RBM 1 Reconstruction error 0.766559
# >> Epoch 514 finished 	RBM 1 Reconstruction error 0.767679
# >> Epoch 515 finished 	RBM 1 Reconstruction error 0.768051
# >> Epoch 516 finished 	RBM 1 Reconstruction error 0.766438
# >> Epoch 517 finished 	RBM 1 Reconstruction error 0.763608
# >> Epoch 518 finished 	RBM 1 Reconstruction error 0.762814
# >> Epoch 519 finished 	RBM 1 Reconstruction error 0.764722
# >> Epoch 520 finished 	RBM 1 Reconstruction error 0.764167
# >> Epoch 521 finished 	RBM 1 Reconstruction error 0.764650
# >> Epoch 522 finished 	RBM 1 Reconstruction error 0.761213
# >> Epoch 523 finished 	RBM 1 Reconstruction error 0.754323
# >> Epoch 524 finished 	RBM 1 Reconstruction error 0.753592
# >> Epoch 525 finished 	RBM 1 Reconstruction error 0.751493
# >> Epoch 526 finished 	RBM 1 Reconstruction error 0.751423
# >> Epoch 527 finished 	RBM 1 Reconstruction error 0.751574
# >> Epoch 528 finished 	RBM 1 Reconstruction error 0.750346
# >> Epoch 529 finished 	RBM 1 Reconstruction error 0.753394
# >> Epoch 530 finished 	RBM 1 Reconstruction error 0.752627
# >> Epoch 531 finished 	RBM 1 Reconstruction error 0.749251
# >> Epoch 532 finished 	RBM 1 Reconstruction error 0.751176
# >> Epoch 533 finished 	RBM 1 Reconstruction error 0.747560
# >> Epoch 534 finished 	RBM 1 Reconstruction error 0.747312
# >> Epoch 535 finished 	RBM 1 Reconstruction error 0.748064
# >> Epoch 536 finished 	RBM 1 Reconstruction error 0.746659
# >> Epoch 537 finished 	RBM 1 Reconstruction error 0.743050
# >> Epoch 538 finished 	RBM 1 Reconstruction error 0.741197
# >> Epoch 539 finished 	RBM 1 Reconstruction error 0.740409
# >> Epoch 540 finished 	RBM 1 Reconstruction error 0.741353
# >> Epoch 541 finished 	RBM 1 Reconstruction error 0.743260
# >> Epoch 542 finished 	RBM 1 Reconstruction error 0.743472
# >> Epoch 543 finished 	RBM 1 Reconstruction error 0.743567
# >> Epoch 544 finished 	RBM 1 Reconstruction error 0.742933
# >> Epoch 545 finished 	RBM 1 Reconstruction error 0.742551
# >> Epoch 546 finished 	RBM 1 Reconstruction error 0.738754
# >> Epoch 547 finished 	RBM 1 Reconstruction error 0.736255
# >> Epoch 548 finished 	RBM 1 Reconstruction error 0.736055
# >> Epoch 549 finished 	RBM 1 Reconstruction error 0.736449
# >> Epoch 550 finished 	RBM 1 Reconstruction error 0.736666
# >> Epoch 551 finished 	RBM 1 Reconstruction error 0.734029
# >> Epoch 552 finished 	RBM 1 Reconstruction error 0.731369
# >> Epoch 553 finished 	RBM 1 Reconstruction error 0.730265
# >> Epoch 554 finished 	RBM 1 Reconstruction error 0.725056
# >> Epoch 555 finished 	RBM 1 Reconstruction error 0.724675
# >> Epoch 556 finished 	RBM 1 Reconstruction error 0.726159
# >> Epoch 557 finished 	RBM 1 Reconstruction error 0.725741
# >> Epoch 558 finished 	RBM 1 Reconstruction error 0.725773
# >> Epoch 559 finished 	RBM 1 Reconstruction error 0.725419
# >> Epoch 560 finished 	RBM 1 Reconstruction error 0.724081
# >> Epoch 561 finished 	RBM 1 Reconstruction error 0.722730
# >> Epoch 562 finished 	RBM 1 Reconstruction error 0.723222
# >> Epoch 563 finished 	RBM 1 Reconstruction error 0.723929
# >> Epoch 564 finished 	RBM 1 Reconstruction error 0.721526
# >> Epoch 565 finished 	RBM 1 Reconstruction error 0.722373
# >> Epoch 566 finished 	RBM 1 Reconstruction error 0.719379
# >> Epoch 567 finished 	RBM 1 Reconstruction error 0.720598
# >> Epoch 568 finished 	RBM 1 Reconstruction error 0.718169
# >> Epoch 569 finished 	RBM 1 Reconstruction error 0.715530
# >> Epoch 570 finished 	RBM 1 Reconstruction error 0.716268
# >> Epoch 571 finished 	RBM 1 Reconstruction error 0.714700
# >> Epoch 572 finished 	RBM 1 Reconstruction error 0.715064
# >> Epoch 573 finished 	RBM 1 Reconstruction error 0.713617
# >> Epoch 574 finished 	RBM 1 Reconstruction error 0.714631
# >> Epoch 575 finished 	RBM 1 Reconstruction error 0.714544
# >> Epoch 576 finished 	RBM 1 Reconstruction error 0.713187
# >> Epoch 577 finished 	RBM 1 Reconstruction error 0.715032
# >> Epoch 578 finished 	RBM 1 Reconstruction error 0.712444
# >> Epoch 579 finished 	RBM 1 Reconstruction error 0.712687
# >> Epoch 580 finished 	RBM 1 Reconstruction error 0.711664
# >> Epoch 581 finished 	RBM 1 Reconstruction error 0.713408
# >> Epoch 582 finished 	RBM 1 Reconstruction error 0.711601
# >> Epoch 583 finished 	RBM 1 Reconstruction error 0.710858
# >> Epoch 584 finished 	RBM 1 Reconstruction error 0.708638
# >> Epoch 585 finished 	RBM 1 Reconstruction error 0.706374
# >> Epoch 586 finished 	RBM 1 Reconstruction error 0.707134
# >> Epoch 587 finished 	RBM 1 Reconstruction error 0.707482
# >> Epoch 588 finished 	RBM 1 Reconstruction error 0.707149
# >> Epoch 589 finished 	RBM 1 Reconstruction error 0.703976
# >> Epoch 590 finished 	RBM 1 Reconstruction error 0.705139
# >> Epoch 591 finished 	RBM 1 Reconstruction error 0.702238
# >> Epoch 592 finished 	RBM 1 Reconstruction error 0.703001
# >> Epoch 593 finished 	RBM 1 Reconstruction error 0.698310
# >> Epoch 594 finished 	RBM 1 Reconstruction error 0.700448
# >> Epoch 595 finished 	RBM 1 Reconstruction error 0.703168
# >> Epoch 596 finished 	RBM 1 Reconstruction error 0.704244
# >> Epoch 597 finished 	RBM 1 Reconstruction error 0.702373
# >> Epoch 598 finished 	RBM 1 Reconstruction error 0.702425
# >> Epoch 599 finished 	RBM 1 Reconstruction error 0.699878
# >> Epoch 600 finished 	RBM 1 Reconstruction error 0.698797
# >> Epoch 601 finished 	RBM 1 Reconstruction error 0.697778
# >> Epoch 602 finished 	RBM 1 Reconstruction error 0.699080
# >> Epoch 603 finished 	RBM 1 Reconstruction error 0.696311
# >> Epoch 604 finished 	RBM 1 Reconstruction error 0.696586
# >> Epoch 605 finished 	RBM 1 Reconstruction error 0.693359
# >> Epoch 606 finished 	RBM 1 Reconstruction error 0.693388
# >> Epoch 607 finished 	RBM 1 Reconstruction error 0.694186
# >> Epoch 608 finished 	RBM 1 Reconstruction error 0.691157
# >> Epoch 609 finished 	RBM 1 Reconstruction error 0.692225
# >> Epoch 610 finished 	RBM 1 Reconstruction error 0.689915
# >> Epoch 611 finished 	RBM 1 Reconstruction error 0.687084
# >> Epoch 612 finished 	RBM 1 Reconstruction error 0.687678
# >> Epoch 613 finished 	RBM 1 Reconstruction error 0.686409
# >> Epoch 614 finished 	RBM 1 Reconstruction error 0.687860
# >> Epoch 615 finished 	RBM 1 Reconstruction error 0.689779
# >> Epoch 616 finished 	RBM 1 Reconstruction error 0.688247
# >> Epoch 617 finished 	RBM 1 Reconstruction error 0.686749
# >> Epoch 618 finished 	RBM 1 Reconstruction error 0.684377
# >> Epoch 619 finished 	RBM 1 Reconstruction error 0.683448
# >> Epoch 620 finished 	RBM 1 Reconstruction error 0.680956
# >> Epoch 621 finished 	RBM 1 Reconstruction error 0.679728
# >> Epoch 622 finished 	RBM 1 Reconstruction error 0.680376
# >> Epoch 623 finished 	RBM 1 Reconstruction error 0.681598
# >> Epoch 624 finished 	RBM 1 Reconstruction error 0.677749
# >> Epoch 625 finished 	RBM 1 Reconstruction error 0.677328
# >> Epoch 626 finished 	RBM 1 Reconstruction error 0.677090
# >> Epoch 627 finished 	RBM 1 Reconstruction error 0.676480
# >> Epoch 628 finished 	RBM 1 Reconstruction error 0.675367
# >> Epoch 629 finished 	RBM 1 Reconstruction error 0.674217
# >> Epoch 630 finished 	RBM 1 Reconstruction error 0.673823
# >> Epoch 631 finished 	RBM 1 Reconstruction error 0.674387
# >> Epoch 632 finished 	RBM 1 Reconstruction error 0.675870
# >> Epoch 633 finished 	RBM 1 Reconstruction error 0.675321
# >> Epoch 634 finished 	RBM 1 Reconstruction error 0.673614
# >> Epoch 635 finished 	RBM 1 Reconstruction error 0.673980
# >> Epoch 636 finished 	RBM 1 Reconstruction error 0.671296
# >> Epoch 637 finished 	RBM 1 Reconstruction error 0.670159
# >> Epoch 638 finished 	RBM 1 Reconstruction error 0.670823
# >> Epoch 639 finished 	RBM 1 Reconstruction error 0.670491
# >> Epoch 640 finished 	RBM 1 Reconstruction error 0.669552
# >> Epoch 641 finished 	RBM 1 Reconstruction error 0.670774
# >> Epoch 642 finished 	RBM 1 Reconstruction error 0.669759
# >> Epoch 643 finished 	RBM 1 Reconstruction error 0.669860
# >> Epoch 644 finished 	RBM 1 Reconstruction error 0.668040
# >> Epoch 645 finished 	RBM 1 Reconstruction error 0.666860
# >> Epoch 646 finished 	RBM 1 Reconstruction error 0.667634
# >> Epoch 647 finished 	RBM 1 Reconstruction error 0.664133
# >> Epoch 648 finished 	RBM 1 Reconstruction error 0.664376
# >> Epoch 649 finished 	RBM 1 Reconstruction error 0.665376
# >> Epoch 650 finished 	RBM 1 Reconstruction error 0.662236
# >> Epoch 651 finished 	RBM 1 Reconstruction error 0.663612
# >> Epoch 652 finished 	RBM 1 Reconstruction error 0.665771
# >> Epoch 653 finished 	RBM 1 Reconstruction error 0.663958
# >> Epoch 654 finished 	RBM 1 Reconstruction error 0.663589
# >> Epoch 655 finished 	RBM 1 Reconstruction error 0.665812
# >> Epoch 656 finished 	RBM 1 Reconstruction error 0.662663
# >> Epoch 657 finished 	RBM 1 Reconstruction error 0.666114
# >> Epoch 658 finished 	RBM 1 Reconstruction error 0.663648
# >> Epoch 659 finished 	RBM 1 Reconstruction error 0.661063
# >> Epoch 660 finished 	RBM 1 Reconstruction error 0.660957
# >> Epoch 661 finished 	RBM 1 Reconstruction error 0.657839
# >> Epoch 662 finished 	RBM 1 Reconstruction error 0.655906
# >> Epoch 663 finished 	RBM 1 Reconstruction error 0.654798
# >> Epoch 664 finished 	RBM 1 Reconstruction error 0.655397
# >> Epoch 665 finished 	RBM 1 Reconstruction error 0.654678
# >> Epoch 666 finished 	RBM 1 Reconstruction error 0.650296
# >> Epoch 667 finished 	RBM 1 Reconstruction error 0.652856
# >> Epoch 668 finished 	RBM 1 Reconstruction error 0.654605
# >> Epoch 669 finished 	RBM 1 Reconstruction error 0.654121
# >> Epoch 670 finished 	RBM 1 Reconstruction error 0.653375
# >> Epoch 671 finished 	RBM 1 Reconstruction error 0.654166
# >> Epoch 672 finished 	RBM 1 Reconstruction error 0.655260
# >> Epoch 673 finished 	RBM 1 Reconstruction error 0.652876
# >> Epoch 674 finished 	RBM 1 Reconstruction error 0.652569
# >> Epoch 675 finished 	RBM 1 Reconstruction error 0.652118
# >> Epoch 676 finished 	RBM 1 Reconstruction error 0.650266
# >> Epoch 677 finished 	RBM 1 Reconstruction error 0.649520
# >> Epoch 678 finished 	RBM 1 Reconstruction error 0.647730
# >> Epoch 679 finished 	RBM 1 Reconstruction error 0.647845
# >> Epoch 680 finished 	RBM 1 Reconstruction error 0.647304
# >> Epoch 681 finished 	RBM 1 Reconstruction error 0.645559
# >> Epoch 682 finished 	RBM 1 Reconstruction error 0.646873
# >> Epoch 683 finished 	RBM 1 Reconstruction error 0.647053
# >> Epoch 684 finished 	RBM 1 Reconstruction error 0.649494
# >> Epoch 685 finished 	RBM 1 Reconstruction error 0.648836
# >> Epoch 686 finished 	RBM 1 Reconstruction error 0.649301
# >> Epoch 687 finished 	RBM 1 Reconstruction error 0.648084
# >> Epoch 688 finished 	RBM 1 Reconstruction error 0.647636
# >> Epoch 689 finished 	RBM 1 Reconstruction error 0.648800
# >> Epoch 690 finished 	RBM 1 Reconstruction error 0.648030
# >> Epoch 691 finished 	RBM 1 Reconstruction error 0.645656
# >> Epoch 692 finished 	RBM 1 Reconstruction error 0.645905
# >> Epoch 693 finished 	RBM 1 Reconstruction error 0.645771
# >> Epoch 694 finished 	RBM 1 Reconstruction error 0.646101
# >> Epoch 695 finished 	RBM 1 Reconstruction error 0.644836
# >> Epoch 696 finished 	RBM 1 Reconstruction error 0.645008
# >> Epoch 697 finished 	RBM 1 Reconstruction error 0.644767
# >> Epoch 698 finished 	RBM 1 Reconstruction error 0.641873
# >> Epoch 699 finished 	RBM 1 Reconstruction error 0.642037
# >> Epoch 700 finished 	RBM 1 Reconstruction error 0.641649
# >> Epoch 1 finished 	RBM 2 Reconstruction error 7.212233
# >> Epoch 2 finished 	RBM 2 Reconstruction error 7.199814
# >> Epoch 3 finished 	RBM 2 Reconstruction error 7.196790
# >> Epoch 4 finished 	RBM 2 Reconstruction error 7.169540
# >> Epoch 5 finished 	RBM 2 Reconstruction error 7.184329
# >> Epoch 6 finished 	RBM 2 Reconstruction error 7.176846
# >> Epoch 7 finished 	RBM 2 Reconstruction error 7.175613
# >> Epoch 8 finished 	RBM 2 Reconstruction error 7.167821
# >> Epoch 9 finished 	RBM 2 Reconstruction error 7.168256
# >> Epoch 10 finished 	RBM 2 Reconstruction error 7.161203
# >> Epoch 11 finished 	RBM 2 Reconstruction error 7.157471
# >> Epoch 12 finished 	RBM 2 Reconstruction error 7.149033
# >> Epoch 13 finished 	RBM 2 Reconstruction error 7.115160
# >> Epoch 14 finished 	RBM 2 Reconstruction error 7.118517
# >> Epoch 15 finished 	RBM 2 Reconstruction error 7.122827
# >> Epoch 16 finished 	RBM 2 Reconstruction error 7.081274
# >> Epoch 17 finished 	RBM 2 Reconstruction error 7.060476
# >> Epoch 18 finished 	RBM 2 Reconstruction error 7.035476
# >> Epoch 19 finished 	RBM 2 Reconstruction error 6.983215
# ...
# >> Epoch 436 finished 	RBM 2 Reconstruction error 2.237064
# >> Epoch 437 finished 	RBM 2 Reconstruction error 2.244078
# >> Epoch 438 finished 	RBM 2 Reconstruction error 2.246229
# >> Epoch 439 finished 	RBM 2 Reconstruction error 2.246975
# >> Epoch 440 finished 	RBM 2 Reconstruction error 2.238530
# >> Epoch 441 finished 	RBM 2 Reconstruction error 2.246411
# >> Epoch 442 finished 	RBM 2 Reconstruction error 2.225359
# >> Epoch 443 finished 	RBM 2 Reconstruction error 2.221142
# >> Epoch 444 finished 	RBM 2 Reconstruction error 2.216527
# >> Epoch 445 finished 	RBM 2 Reconstruction error 2.228057
# >> Epoch 446 finished 	RBM 2 Reconstruction error 2.247835
# >> Epoch 447 finished 	RBM 2 Reconstruction error 2.232901
# >> Epoch 448 finished 	RBM 2 Reconstruction error 2.243751
# >> Epoch 449 finished 	RBM 2 Reconstruction error 2.232802
# >> Epoch 450 finished 	RBM 2 Reconstruction error 2.229197
# >> Epoch 451 finished 	RBM 2 Reconstruction error 2.221204
# >> Epoch 452 finished 	RBM 2 Reconstruction error 2.236623
# >> Epoch 453 finished 	RBM 2 Reconstruction error 2.206475
# >> Epoch 454 finished 	RBM 2 Reconstruction error 2.214028
# >> Epoch 455 finished 	RBM 2 Reconstruction error 2.210751
# >> Epoch 456 finished 	RBM 2 Reconstruction error 2.224557
# >> Epoch 457 finished 	RBM 2 Reconstruction error 2.233140
# >> Epoch 458 finished 	RBM 2 Reconstruction error 2.218435
# >> Epoch 459 finished 	RBM 2 Reconstruction error 2.230611
# >> Epoch 460 finished 	RBM 2 Reconstruction error 2.239035
# >> Epoch 461 finished 	RBM 2 Reconstruction error 2.218013
# >> Epoch 462 finished 	RBM 2 Reconstruction error 2.221309
# >> Epoch 463 finished 	RBM 2 Reconstruction error 2.218338
# >> Epoch 464 finished 	RBM 2 Reconstruction error 2.214612
# >> Epoch 465 finished 	RBM 2 Reconstruction error 2.204528
# >> Epoch 466 finished 	RBM 2 Reconstruction error 2.235010
# >> Epoch 467 finished 	RBM 2 Reconstruction error 2.230504
# >> Epoch 468 finished 	RBM 2 Reconstruction error 2.222459
# >> Epoch 469 finished 	RBM 2 Reconstruction error 2.220764
# >> Epoch 470 finished 	RBM 2 Reconstruction error 2.215260
# >> Epoch 471 finished 	RBM 2 Reconstruction error 2.219084
# >> Epoch 472 finished 	RBM 2 Reconstruction error 2.202532
# >> Epoch 473 finished 	RBM 2 Reconstruction error 2.192682
# >> Epoch 474 finished 	RBM 2 Reconstruction error 2.201555
# >> Epoch 475 finished 	RBM 2 Reconstruction error 2.206128
# >> Epoch 476 finished 	RBM 2 Reconstruction error 2.206848
# >> Epoch 477 finished 	RBM 2 Reconstruction error 2.219492
# >> Epoch 478 finished 	RBM 2 Reconstruction error 2.208300
# >> Epoch 479 finished 	RBM 2 Reconstruction error 2.192920
# >> Epoch 480 finished 	RBM 2 Reconstruction error 2.218569
# >> Epoch 481 finished 	RBM 2 Reconstruction error 2.223158
# >> Epoch 482 finished 	RBM 2 Reconstruction error 2.206810
# >> Epoch 483 finished 	RBM 2 Reconstruction error 2.197339
# >> Epoch 484 finished 	RBM 2 Reconstruction error 2.186801
# >> Epoch 485 finished 	RBM 2 Reconstruction error 2.202849
# >> Epoch 486 finished 	RBM 2 Reconstruction error 2.200843
# >> Epoch 487 finished 	RBM 2 Reconstruction error 2.200633
# >> Epoch 488 finished 	RBM 2 Reconstruction error 2.197695
# >> Epoch 489 finished 	RBM 2 Reconstruction error 2.198049
# >> Epoch 490 finished 	RBM 2 Reconstruction error 2.188980
# >> Epoch 491 finished 	RBM 2 Reconstruction error 2.200550
# >> Epoch 492 finished 	RBM 2 Reconstruction error 2.228889
# >> Epoch 493 finished 	RBM 2 Reconstruction error 2.209673
# >> Epoch 494 finished 	RBM 2 Reconstruction error 2.210080
# >> Epoch 495 finished 	RBM 2 Reconstruction error 2.183194
# >> Epoch 496 finished 	RBM 2 Reconstruction error 2.195797
# >> Epoch 497 finished 	RBM 2 Reconstruction error 2.175302
# >> Epoch 498 finished 	RBM 2 Reconstruction error 2.170954
# >> Epoch 499 finished 	RBM 2 Reconstruction error 2.175917
# >> Epoch 500 finished 	RBM 2 Reconstruction error 2.177921
# >> Epoch 501 finished 	RBM 2 Reconstruction error 2.190609
# >> Epoch 502 finished 	RBM 2 Reconstruction error 2.188249
# >> Epoch 503 finished 	RBM 2 Reconstruction error 2.166092
# >> Epoch 504 finished 	RBM 2 Reconstruction error 2.175787
# >> Epoch 505 finished 	RBM 2 Reconstruction error 2.185593
# >> Epoch 506 finished 	RBM 2 Reconstruction error 2.193375
# >> Epoch 507 finished 	RBM 2 Reconstruction error 2.173519
# >> Epoch 508 finished 	RBM 2 Reconstruction error 2.170788
# >> Epoch 509 finished 	RBM 2 Reconstruction error 2.178558
# >> Epoch 510 finished 	RBM 2 Reconstruction error 2.179326
# >> Epoch 511 finished 	RBM 2 Reconstruction error 2.167397
# >> Epoch 512 finished 	RBM 2 Reconstruction error 2.164303
# >> Epoch 513 finished 	RBM 2 Reconstruction error 2.196686
# >> Epoch 514 finished 	RBM 2 Reconstruction error 2.190557
# >> Epoch 515 finished 	RBM 2 Reconstruction error 2.196270
# >> Epoch 516 finished 	RBM 2 Reconstruction error 2.189602
# >> Epoch 517 finished 	RBM 2 Reconstruction error 2.184665
# >> Epoch 518 finished 	RBM 2 Reconstruction error 2.175744
# >> Epoch 519 finished 	RBM 2 Reconstruction error 2.184491
# >> Epoch 520 finished 	RBM 2 Reconstruction error 2.171916
# >> Epoch 521 finished 	RBM 2 Reconstruction error 2.164371
# >> Epoch 522 finished 	RBM 2 Reconstruction error 2.178714
# >> Epoch 523 finished 	RBM 2 Reconstruction error 2.171623
# >> Epoch 524 finished 	RBM 2 Reconstruction error 2.165808
# >> Epoch 525 finished 	RBM 2 Reconstruction error 2.174909
# >> Epoch 526 finished 	RBM 2 Reconstruction error 2.159265
# >> Epoch 527 finished 	RBM 2 Reconstruction error 2.160661
# >> Epoch 528 finished 	RBM 2 Reconstruction error 2.166025
# >> Epoch 529 finished 	RBM 2 Reconstruction error 2.168331
# >> Epoch 530 finished 	RBM 2 Reconstruction error 2.156846
# >> Epoch 531 finished 	RBM 2 Reconstruction error 2.162920
# >> Epoch 532 finished 	RBM 2 Reconstruction error 2.142682
# >> Epoch 533 finished 	RBM 2 Reconstruction error 2.139452
# >> Epoch 534 finished 	RBM 2 Reconstruction error 2.139406
# >> Epoch 535 finished 	RBM 2 Reconstruction error 2.164978
# >> Epoch 536 finished 	RBM 2 Reconstruction error 2.149800
# >> Epoch 537 finished 	RBM 2 Reconstruction error 2.180662
# >> Epoch 538 finished 	RBM 2 Reconstruction error 2.164290
# >> Epoch 539 finished 	RBM 2 Reconstruction error 2.152193
# >> Epoch 540 finished 	RBM 2 Reconstruction error 2.168287
# >> Epoch 541 finished 	RBM 2 Reconstruction error 2.153099
# >> Epoch 542 finished 	RBM 2 Reconstruction error 2.184569
# >> Epoch 543 finished 	RBM 2 Reconstruction error 2.149789
# >> Epoch 544 finished 	RBM 2 Reconstruction error 2.152979
# >> Epoch 545 finished 	RBM 2 Reconstruction error 2.160195
# >> Epoch 546 finished 	RBM 2 Reconstruction error 2.156852
# >> Epoch 547 finished 	RBM 2 Reconstruction error 2.174243
# >> Epoch 548 finished 	RBM 2 Reconstruction error 2.149723
# >> Epoch 549 finished 	RBM 2 Reconstruction error 2.135889
# >> Epoch 550 finished 	RBM 2 Reconstruction error 2.155793
# >> Epoch 551 finished 	RBM 2 Reconstruction error 2.146993
# >> Epoch 552 finished 	RBM 2 Reconstruction error 2.137991
# >> Epoch 553 finished 	RBM 2 Reconstruction error 2.148322
# >> Epoch 554 finished 	RBM 2 Reconstruction error 2.135253
# >> Epoch 555 finished 	RBM 2 Reconstruction error 2.142426
# >> Epoch 556 finished 	RBM 2 Reconstruction error 2.146664
# >> Epoch 557 finished 	RBM 2 Reconstruction error 2.138133
# >> Epoch 558 finished 	RBM 2 Reconstruction error 2.136015
# >> Epoch 559 finished 	RBM 2 Reconstruction error 2.134780
# >> Epoch 560 finished 	RBM 2 Reconstruction error 2.117725
# >> Epoch 561 finished 	RBM 2 Reconstruction error 2.139900
# >> Epoch 562 finished 	RBM 2 Reconstruction error 2.124648
# >> Epoch 563 finished 	RBM 2 Reconstruction error 2.138960
# >> Epoch 564 finished 	RBM 2 Reconstruction error 2.141158
# >> Epoch 565 finished 	RBM 2 Reconstruction error 2.121944
# >> Epoch 566 finished 	RBM 2 Reconstruction error 2.129131
# >> Epoch 567 finished 	RBM 2 Reconstruction error 2.138786
# >> Epoch 568 finished 	RBM 2 Reconstruction error 2.146455
# >> Epoch 569 finished 	RBM 2 Reconstruction error 2.136221
# >> Epoch 570 finished 	RBM 2 Reconstruction error 2.132145
# >> Epoch 571 finished 	RBM 2 Reconstruction error 2.130032
# >> Epoch 572 finished 	RBM 2 Reconstruction error 2.125171
# >> Epoch 573 finished 	RBM 2 Reconstruction error 2.120601
# >> Epoch 574 finished 	RBM 2 Reconstruction error 2.143284
# >> Epoch 575 finished 	RBM 2 Reconstruction error 2.130949
# >> Epoch 576 finished 	RBM 2 Reconstruction error 2.162649
# >> Epoch 577 finished 	RBM 2 Reconstruction error 2.168416
# >> Epoch 578 finished 	RBM 2 Reconstruction error 2.145975
# >> Epoch 579 finished 	RBM 2 Reconstruction error 2.123169
# >> Epoch 580 finished 	RBM 2 Reconstruction error 2.141999
# >> Epoch 581 finished 	RBM 2 Reconstruction error 2.133259
# >> Epoch 582 finished 	RBM 2 Reconstruction error 2.125237
# >> Epoch 583 finished 	RBM 2 Reconstruction error 2.132557
# >> Epoch 584 finished 	RBM 2 Reconstruction error 2.128557
# >> Epoch 585 finished 	RBM 2 Reconstruction error 2.109906
# >> Epoch 586 finished 	RBM 2 Reconstruction error 2.109859
# >> Epoch 587 finished 	RBM 2 Reconstruction error 2.109065
# >> Epoch 588 finished 	RBM 2 Reconstruction error 2.123663
# >> Epoch 589 finished 	RBM 2 Reconstruction error 2.117522
# >> Epoch 590 finished 	RBM 2 Reconstruction error 2.129297
# >> Epoch 591 finished 	RBM 2 Reconstruction error 2.124880
# >> Epoch 592 finished 	RBM 2 Reconstruction error 2.136297
# >> Epoch 593 finished 	RBM 2 Reconstruction error 2.130676
# >> Epoch 594 finished 	RBM 2 Reconstruction error 2.121162
# >> Epoch 595 finished 	RBM 2 Reconstruction error 2.116291
# >> Epoch 596 finished 	RBM 2 Reconstruction error 2.104393
# >> Epoch 597 finished 	RBM 2 Reconstruction error 2.111820
# >> Epoch 598 finished 	RBM 2 Reconstruction error 2.099743
# >> Epoch 599 finished 	RBM 2 Reconstruction error 2.129682
# >> Epoch 600 finished 	RBM 2 Reconstruction error 2.102447
# >> Epoch 601 finished 	RBM 2 Reconstruction error 2.109811
# >> Epoch 602 finished 	RBM 2 Reconstruction error 2.109652
# >> Epoch 603 finished 	RBM 2 Reconstruction error 2.106522
# >> Epoch 604 finished 	RBM 2 Reconstruction error 2.114805
# >> Epoch 605 finished 	RBM 2 Reconstruction error 2.113223
# >> Epoch 606 finished 	RBM 2 Reconstruction error 2.118740
# >> Epoch 607 finished 	RBM 2 Reconstruction error 2.108232
# >> Epoch 608 finished 	RBM 2 Reconstruction error 2.109760
# >> Epoch 609 finished 	RBM 2 Reconstruction error 2.113359
# >> Epoch 610 finished 	RBM 2 Reconstruction error 2.101750
# >> Epoch 611 finished 	RBM 2 Reconstruction error 2.092981
# >> Epoch 612 finished 	RBM 2 Reconstruction error 2.103467
# >> Epoch 613 finished 	RBM 2 Reconstruction error 2.111157
# >> Epoch 614 finished 	RBM 2 Reconstruction error 2.089395
# >> Epoch 615 finished 	RBM 2 Reconstruction error 2.097938
# >> Epoch 616 finished 	RBM 2 Reconstruction error 2.101795
# >> Epoch 617 finished 	RBM 2 Reconstruction error 2.101870
# >> Epoch 618 finished 	RBM 2 Reconstruction error 2.096644
# >> Epoch 619 finished 	RBM 2 Reconstruction error 2.098589
# >> Epoch 620 finished 	RBM 2 Reconstruction error 2.096174
# >> Epoch 621 finished 	RBM 2 Reconstruction error 2.081424
# >> Epoch 622 finished 	RBM 2 Reconstruction error 2.097358
# >> Epoch 623 finished 	RBM 2 Reconstruction error 2.101904
# >> Epoch 624 finished 	RBM 2 Reconstruction error 2.100544
# >> Epoch 625 finished 	RBM 2 Reconstruction error 2.090262
# >> Epoch 626 finished 	RBM 2 Reconstruction error 2.094385
# >> Epoch 627 finished 	RBM 2 Reconstruction error 2.101949
# >> Epoch 628 finished 	RBM 2 Reconstruction error 2.092645
# >> Epoch 629 finished 	RBM 2 Reconstruction error 2.094589
# >> Epoch 630 finished 	RBM 2 Reconstruction error 2.114865
# >> Epoch 631 finished 	RBM 2 Reconstruction error 2.110791
# >> Epoch 632 finished 	RBM 2 Reconstruction error 2.097494
# >> Epoch 633 finished 	RBM 2 Reconstruction error 2.075281
# >> Epoch 634 finished 	RBM 2 Reconstruction error 2.082981
# >> Epoch 635 finished 	RBM 2 Reconstruction error 2.094747
# >> Epoch 636 finished 	RBM 2 Reconstruction error 2.095148
# >> Epoch 637 finished 	RBM 2 Reconstruction error 2.085922
# >> Epoch 638 finished 	RBM 2 Reconstruction error 2.089379
# >> Epoch 639 finished 	RBM 2 Reconstruction error 2.092340
# >> Epoch 640 finished 	RBM 2 Reconstruction error 2.089568
# >> Epoch 641 finished 	RBM 2 Reconstruction error 2.089889
# >> Epoch 642 finished 	RBM 2 Reconstruction error 2.069169
# >> Epoch 643 finished 	RBM 2 Reconstruction error 2.076777
# >> Epoch 644 finished 	RBM 2 Reconstruction error 2.082043
# >> Epoch 645 finished 	RBM 2 Reconstruction error 2.091193
# >> Epoch 646 finished 	RBM 2 Reconstruction error 2.078437
# >> Epoch 647 finished 	RBM 2 Reconstruction error 2.082387
# >> Epoch 648 finished 	RBM 2 Reconstruction error 2.086150
# >> Epoch 649 finished 	RBM 2 Reconstruction error 2.091868
# >> Epoch 650 finished 	RBM 2 Reconstruction error 2.084671
# >> Epoch 651 finished 	RBM 2 Reconstruction error 2.075646
# >> Epoch 652 finished 	RBM 2 Reconstruction error 2.081619
# >> Epoch 653 finished 	RBM 2 Reconstruction error 2.081231
# >> Epoch 654 finished 	RBM 2 Reconstruction error 2.074194
# >> Epoch 655 finished 	RBM 2 Reconstruction error 2.078800
# >> Epoch 656 finished 	RBM 2 Reconstruction error 2.087964
# >> Epoch 657 finished 	RBM 2 Reconstruction error 2.089961
# >> Epoch 658 finished 	RBM 2 Reconstruction error 2.093573
# >> Epoch 659 finished 	RBM 2 Reconstruction error 2.079623
# >> Epoch 660 finished 	RBM 2 Reconstruction error 2.079475
# >> Epoch 661 finished 	RBM 2 Reconstruction error 2.080633
# >> Epoch 662 finished 	RBM 2 Reconstruction error 2.067569
# >> Epoch 663 finished 	RBM 2 Reconstruction error 2.080897
# >> Epoch 664 finished 	RBM 2 Reconstruction error 2.083263
# >> Epoch 665 finished 	RBM 2 Reconstruction error 2.080910
# >> Epoch 666 finished 	RBM 2 Reconstruction error 2.079584
# >> Epoch 667 finished 	RBM 2 Reconstruction error 2.080279
# >> Epoch 668 finished 	RBM 2 Reconstruction error 2.084162
# >> Epoch 669 finished 	RBM 2 Reconstruction error 2.069031
# >> Epoch 670 finished 	RBM 2 Reconstruction error 2.078646
# >> Epoch 671 finished 	RBM 2 Reconstruction error 2.078950
# >> Epoch 672 finished 	RBM 2 Reconstruction error 2.077237
# >> Epoch 673 finished 	RBM 2 Reconstruction error 2.068319
# >> Epoch 674 finished 	RBM 2 Reconstruction error 2.081366
# >> Epoch 675 finished 	RBM 2 Reconstruction error 2.078447
# >> Epoch 676 finished 	RBM 2 Reconstruction error 2.087521
# >> Epoch 677 finished 	RBM 2 Reconstruction error 2.086184
# >> Epoch 678 finished 	RBM 2 Reconstruction error 2.066871
# >> Epoch 679 finished 	RBM 2 Reconstruction error 2.075175
# >> Epoch 680 finished 	RBM 2 Reconstruction error 2.065494
# >> Epoch 681 finished 	RBM 2 Reconstruction error 2.073076
# >> Epoch 682 finished 	RBM 2 Reconstruction error 2.077842
# >> Epoch 683 finished 	RBM 2 Reconstruction error 2.066749
# >> Epoch 684 finished 	RBM 2 Reconstruction error 2.064198
# >> Epoch 685 finished 	RBM 2 Reconstruction error 2.056737
# >> Epoch 686 finished 	RBM 2 Reconstruction error 2.065863
# >> Epoch 687 finished 	RBM 2 Reconstruction error 2.051566
# >> Epoch 688 finished 	RBM 2 Reconstruction error 2.046160
# >> Epoch 689 finished 	RBM 2 Reconstruction error 2.055337
# >> Epoch 690 finished 	RBM 2 Reconstruction error 2.041257
# >> Epoch 691 finished 	RBM 2 Reconstruction error 2.052991
# >> Epoch 692 finished 	RBM 2 Reconstruction error 2.048944
# >> Epoch 693 finished 	RBM 2 Reconstruction error 2.047801
# >> Epoch 694 finished 	RBM 2 Reconstruction error 2.047618
# >> Epoch 695 finished 	RBM 2 Reconstruction error 2.054256
# >> Epoch 696 finished 	RBM 2 Reconstruction error 2.084596
# >> Epoch 697 finished 	RBM 2 Reconstruction error 2.065660
# >> Epoch 698 finished 	RBM 2 Reconstruction error 2.062910
# >> Epoch 699 finished 	RBM 2 Reconstruction error 2.065726
# >> Epoch 700 finished 	RBM 2 Reconstruction error 2.055626
# Unsupervised training time:  92.20878267288208  seconds
# Finetuning with SVM
# Time fitting the data:  0.021941184997558594
# bins  [0, 1, 2, 3]  digitized 2  [[4 4 3 4]
#  [4 4 4 4]]  mat abs  [[ 3  7  2 13]
#  [17  6  3 20]]
# Test data  Model accuracy : 0.6470588235294118
# Test data  Confusion matrix :
#  [[38 18]
#  [18 28]]

# %%
evaluation_model_MLSIM(1)
# Out:
# bins  [0, 1, 2, 3]  digitized 2  [[4 4 4 4]
#  [4 3 3 4]]  mat abs  [[10 10  5  6]
#  [ 5  2  2  5]]
# Model MLSIM pour:  Perception
# 405 9
# Nbr students: 405
# Learning traces dimension: 9
# Initialize weigths [[ 0.08445475  0.04839338  0.1041746   0.00837779  0.00043698  0.00276273
#    0.02109294 -0.09060167 -0.0561663 ]
#  [ 0.04524727  0.00858941 -0.00652396 -0.04225748 -0.103246    0.02828774
#   -0.08800544  0.05958094  0.08059222]
#  [ 0.01782571  0.04744115 -0.0426989   0.0263591   0.04682413  0.0906379
#    0.09374891 -0.00351502  0.09082323]
#  [-0.06883402  0.09702214  0.06660083  0.02530898 -0.0506772  -0.07718517
#    0.03746995  0.06590624  0.04341451]
#  [ 0.03026961 -0.10439247  0.06432098  0.09658943  0.1011703  -0.08741697
#    0.00044436  0.05036616  0.02511272]
#  [ 0.04186632  0.11018115 -0.01378733  0.10527495 -0.11092328  0.03575614
#    0.07960883 -0.09022406  0.01561606]
#  [-0.10145339  0.07226221 -0.09431854  0.03465013  0.08847466  0.03289791
#    0.07679725 -0.08618956  0.0874368 ]
#  [ 0.07411989  0.0288758  -0.09075059  0.05970771 -0.04867979 -0.04900516
#   -0.08887502  0.01313409  0.05588652]
#  [-0.00938461  0.04104901  0.04779702 -0.04991472  0.08728351  0.01033077
#    0.00783718 -0.10263936  0.10598202]
#  [ 0.05103418 -0.10406374 -0.08423035  0.01323412  0.03759164  0.01559088
#    0.10157613 -0.04729238  0.02314978]]
# Initialize weigths [[ 0.04512253  0.0537326  -0.04031714  0.01267907  0.05994203 -0.00141722
#   -0.06516918 -0.04344353  0.0499518   0.04595426]
#  [-0.08722625 -0.08901906 -0.06827076 -0.04618072  0.01482233  0.070852
#   -0.08598064 -0.07975974 -0.09675775 -0.02120129]
#  [ 0.06461941  0.09059557  0.08810142  0.03752038 -0.05744282 -0.02862755
#   -0.03458889 -0.00553951 -0.08909085  0.04745166]
#  [-0.0020419  -0.00330554  0.09308029 -0.01821999 -0.07584015 -0.00422551
#   -0.01899442 -0.06206958  0.01295773 -0.041124  ]
#  [-0.0680179   0.02533447 -0.09101494 -0.00173808 -0.07358184  0.06609008
#    0.0267382   0.06705324 -0.05095538  0.06408391]
#  [ 0.04755299 -0.01028111  0.02245055  0.04504161  0.05205651  0.06752166
#    0.06728409 -0.02424227 -0.0284872  -0.09766872]
#  [ 0.05600201  0.00283756  0.03100113 -0.0882615   0.05447485  0.02894792
#    0.08277625  0.09367381  0.0994751  -0.00021551]
#  [ 0.09682743 -0.01731973 -0.06452432  0.08705164  0.06880775  0.01410383
#    0.06826612 -0.02925321 -0.01197689 -0.070196  ]
#  [ 0.06055453  0.00542786 -0.03796097  0.00958921  0.03832303 -0.0341826
#   -0.00920931  0.06847705 -0.05098132 -0.05732604]
#  [ 0.06285894  0.08963369 -0.05199552  0.0729553  -0.04804472 -0.00915175
#    0.07866448 -0.03522247  0.01544144  0.01325207]]
# Training the Hybrid Deep Belief Net model
# ................
# E:\paperResearch\MLSIM\extraction.py:21: RuntimeWarning: Mean of empty slice.
#   bin_means = [mat_abs[digitized == i].mean() for i in range(1, len(bins))]
# >> Epoch 1 finished 	RBM 1 Reconstruction error 3.166246
# >> Epoch 2 finished 	RBM 1 Reconstruction error 2.220307
# >> Epoch 3 finished 	RBM 1 Reconstruction error 1.962497
# >> Epoch 4 finished 	RBM 1 Reconstruction error 1.850679
# >> Epoch 5 finished 	RBM 1 Reconstruction error 1.811368
# >> Epoch 6 finished 	RBM 1 Reconstruction error 1.795723
# >> Epoch 7 finished 	RBM 1 Reconstruction error 1.784030
# >> Epoch 8 finished 	RBM 1 Reconstruction error 1.776670
# >> Epoch 9 finished 	RBM 1 Reconstruction error 1.770678
# >> Epoch 10 finished 	RBM 1 Reconstruction error 1.768075
# >> Epoch 11 finished 	RBM 1 Reconstruction error 1.768444
# >> Epoch 12 finished 	RBM 1 Reconstruction error 1.765416
# >> Epoch 13 finished 	RBM 1 Reconstruction error 1.765196
# >> Epoch 14 finished 	RBM 1 Reconstruction error 1.764546
# >> Epoch 15 finished 	RBM 1 Reconstruction error 1.763835
# >> Epoch 16 finished 	RBM 1 Reconstruction error 1.762030
# >> Epoch 17 finished 	RBM 1 Reconstruction error 1.762676
# >> Epoch 18 finished 	RBM 1 Reconstruction error 1.759787
# >> Epoch 19 finished 	RBM 1 Reconstruction error 1.759602
# >> Epoch 20 finished 	RBM 1 Reconstruction error 1.758300
# >> Epoch 21 finished 	RBM 1 Reconstruction error 1.760251
# >> Epoch 22 finished 	RBM 1 Reconstruction error 1.758672
# >> Epoch 23 finished 	RBM 1 Reconstruction error 1.757988
# >> Epoch 24 finished 	RBM 1 Reconstruction error 1.758016
# >> Epoch 25 finished 	RBM 1 Reconstruction error 1.758696
# >> Epoch 26 finished 	RBM 1 Reconstruction error 1.757494
# >> Epoch 27 finished 	RBM 1 Reconstruction error 1.755906
# >> Epoch 28 finished 	RBM 1 Reconstruction error 1.755761
# >> Epoch 29 finished 	RBM 1 Reconstruction error 1.755634
# >> Epoch 30 finished 	RBM 1 Reconstruction error 1.755168
# >> Epoch 31 finished 	RBM 1 Reconstruction error 1.753949
# >> Epoch 32 finished 	RBM 1 Reconstruction error 1.753135
# >> Epoch 33 finished 	RBM 1 Reconstruction error 1.752345
# >> Epoch 34 finished 	RBM 1 Reconstruction error 1.752884
# >> Epoch 35 finished 	RBM 1 Reconstruction error 1.752946
# >> Epoch 36 finished 	RBM 1 Reconstruction error 1.752462
# >> Epoch 37 finished 	RBM 1 Reconstruction error 1.752826
# >> Epoch 38 finished 	RBM 1 Reconstruction error 1.751403
# >> Epoch 39 finished 	RBM 1 Reconstruction error 1.749707
# >> Epoch 40 finished 	RBM 1 Reconstruction error 1.748378
# >> Epoch 41 finished 	RBM 1 Reconstruction error 1.748714
# >> Epoch 42 finished 	RBM 1 Reconstruction error 1.748541
# >> Epoch 43 finished 	RBM 1 Reconstruction error 1.747758
# >> Epoch 44 finished 	RBM 1 Reconstruction error 1.747886
# >> Epoch 45 finished 	RBM 1 Reconstruction error 1.747312
# >> Epoch 46 finished 	RBM 1 Reconstruction error 1.746549
# >> Epoch 47 finished 	RBM 1 Reconstruction error 1.747552
# >> Epoch 48 finished 	RBM 1 Reconstruction error 1.748049
# >> Epoch 49 finished 	RBM 1 Reconstruction error 1.747837
# >> Epoch 50 finished 	RBM 1 Reconstruction error 1.747746
# >> Epoch 51 finished 	RBM 1 Reconstruction error 1.746596
# >> Epoch 52 finished 	RBM 1 Reconstruction error 1.745476
# >> Epoch 53 finished 	RBM 1 Reconstruction error 1.744432
# >> Epoch 54 finished 	RBM 1 Reconstruction error 1.743724
# >> Epoch 55 finished 	RBM 1 Reconstruction error 1.744536
# >> Epoch 56 finished 	RBM 1 Reconstruction error 1.743927
# >> Epoch 57 finished 	RBM 1 Reconstruction error 1.741860
# >> Epoch 58 finished 	RBM 1 Reconstruction error 1.741281
# >> Epoch 59 finished 	RBM 1 Reconstruction error 1.740671
# >> Epoch 60 finished 	RBM 1 Reconstruction error 1.738756
# >> Epoch 61 finished 	RBM 1 Reconstruction error 1.737531
# >> Epoch 62 finished 	RBM 1 Reconstruction error 1.737202
# >> Epoch 63 finished 	RBM 1 Reconstruction error 1.737054
# >> Epoch 64 finished 	RBM 1 Reconstruction error 1.737333
# >> Epoch 65 finished 	RBM 1 Reconstruction error 1.737217
# >> Epoch 66 finished 	RBM 1 Reconstruction error 1.736143
# >> Epoch 67 finished 	RBM 1 Reconstruction error 1.736353
# >> Epoch 68 finished 	RBM 1 Reconstruction error 1.735110
# >> Epoch 69 finished 	RBM 1 Reconstruction error 1.734239
# >> Epoch 70 finished 	RBM 1 Reconstruction error 1.733334
# >> Epoch 71 finished 	RBM 1 Reconstruction error 1.733281
# >> Epoch 72 finished 	RBM 1 Reconstruction error 1.732918
# >> Epoch 73 finished 	RBM 1 Reconstruction error 1.734484
# >> Epoch 74 finished 	RBM 1 Reconstruction error 1.733237
# >> Epoch 75 finished 	RBM 1 Reconstruction error 1.733235
# >> Epoch 76 finished 	RBM 1 Reconstruction error 1.731655
# >> Epoch 77 finished 	RBM 1 Reconstruction error 1.730690
# >> Epoch 78 finished 	RBM 1 Reconstruction error 1.730803
# >> Epoch 79 finished 	RBM 1 Reconstruction error 1.728306
# >> Epoch 80 finished 	RBM 1 Reconstruction error 1.726317
# >> Epoch 81 finished 	RBM 1 Reconstruction error 1.726568
# >> Epoch 82 finished 	RBM 1 Reconstruction error 1.726104
# >> Epoch 83 finished 	RBM 1 Reconstruction error 1.725438
# >> Epoch 84 finished 	RBM 1 Reconstruction error 1.725588
# >> Epoch 85 finished 	RBM 1 Reconstruction error 1.725321
# >> Epoch 86 finished 	RBM 1 Reconstruction error 1.724180
# >> Epoch 87 finished 	RBM 1 Reconstruction error 1.721878
# >> Epoch 88 finished 	RBM 1 Reconstruction error 1.722459
# >> Epoch 89 finished 	RBM 1 Reconstruction error 1.721368
# >> Epoch 90 finished 	RBM 1 Reconstruction error 1.721078
# >> Epoch 91 finished 	RBM 1 Reconstruction error 1.720854
# >> Epoch 92 finished 	RBM 1 Reconstruction error 1.720179
# >> Epoch 93 finished 	RBM 1 Reconstruction error 1.718001
# >> Epoch 94 finished 	RBM 1 Reconstruction error 1.716274
# >> Epoch 95 finished 	RBM 1 Reconstruction error 1.715061
# >> Epoch 96 finished 	RBM 1 Reconstruction error 1.714590
# >> Epoch 97 finished 	RBM 1 Reconstruction error 1.713446
# >> Epoch 98 finished 	RBM 1 Reconstruction error 1.712817
# >> Epoch 99 finished 	RBM 1 Reconstruction error 1.711773
# >> Epoch 100 finished 	RBM 1 Reconstruction error 1.711323
# >> Epoch 1 finished 	RBM 2 Reconstruction error 5.633053
# >> Epoch 2 finished 	RBM 2 Reconstruction error 5.379640
# >> Epoch 3 finished 	RBM 2 Reconstruction error 5.370114
# >> Epoch 4 finished 	RBM 2 Reconstruction error 5.367517
# >> Epoch 5 finished 	RBM 2 Reconstruction error 5.364588
# >> Epoch 6 finished 	RBM 2 Reconstruction error 5.368886
# >> Epoch 7 finished 	RBM 2 Reconstruction error 5.372155
# >> Epoch 8 finished 	RBM 2 Reconstruction error 5.364638
# >> Epoch 9 finished 	RBM 2 Reconstruction error 5.363649
# >> Epoch 10 finished 	RBM 2 Reconstruction error 5.364989
# >> Epoch 11 finished 	RBM 2 Reconstruction error 5.371995
# >> Epoch 12 finished 	RBM 2 Reconstruction error 5.374667
# >> Epoch 13 finished 	RBM 2 Reconstruction error 5.363962
# >> Epoch 14 finished 	RBM 2 Reconstruction error 5.362863
# >> Epoch 15 finished 	RBM 2 Reconstruction error 5.364823
# >> Epoch 16 finished 	RBM 2 Reconstruction error 5.364232
# >> Epoch 17 finished 	RBM 2 Reconstruction error 5.364649
# >> Epoch 18 finished 	RBM 2 Reconstruction error 5.369622
# >> Epoch 19 finished 	RBM 2 Reconstruction error 5.365410
# >> Epoch 20 finished 	RBM 2 Reconstruction error 5.361629
# >> Epoch 21 finished 	RBM 2 Reconstruction error 5.372021
# >> Epoch 22 finished 	RBM 2 Reconstruction error 5.363509
# >> Epoch 23 finished 	RBM 2 Reconstruction error 5.366829
# >> Epoch 24 finished 	RBM 2 Reconstruction error 5.364862
# >> Epoch 25 finished 	RBM 2 Reconstruction error 5.362026
# >> Epoch 26 finished 	RBM 2 Reconstruction error 5.364195
# >> Epoch 27 finished 	RBM 2 Reconstruction error 5.360983
# >> Epoch 28 finished 	RBM 2 Reconstruction error 5.361539
# >> Epoch 29 finished 	RBM 2 Reconstruction error 5.365488
# >> Epoch 30 finished 	RBM 2 Reconstruction error 5.361972
# >> Epoch 31 finished 	RBM 2 Reconstruction error 5.366993
# >> Epoch 32 finished 	RBM 2 Reconstruction error 5.370011
# >> Epoch 33 finished 	RBM 2 Reconstruction error 5.365237
# >> Epoch 34 finished 	RBM 2 Reconstruction error 5.369600
# >> Epoch 35 finished 	RBM 2 Reconstruction error 5.369213
# >> Epoch 36 finished 	RBM 2 Reconstruction error 5.365844
# >> Epoch 37 finished 	RBM 2 Reconstruction error 5.366522
# >> Epoch 38 finished 	RBM 2 Reconstruction error 5.368806
# >> Epoch 39 finished 	RBM 2 Reconstruction error 5.360176
# >> Epoch 40 finished 	RBM 2 Reconstruction error 5.359122
# >> Epoch 41 finished 	RBM 2 Reconstruction error 5.364357
# >> Epoch 42 finished 	RBM 2 Reconstruction error 5.362160
# >> Epoch 43 finished 	RBM 2 Reconstruction error 5.360425
# >> Epoch 44 finished 	RBM 2 Reconstruction error 5.361328
# >> Epoch 45 finished 	RBM 2 Reconstruction error 5.367043
# >> Epoch 46 finished 	RBM 2 Reconstruction error 5.361541
# >> Epoch 47 finished 	RBM 2 Reconstruction error 5.365348
# >> Epoch 48 finished 	RBM 2 Reconstruction error 5.360237
# >> Epoch 49 finished 	RBM 2 Reconstruction error 5.359085
# >> Epoch 50 finished 	RBM 2 Reconstruction error 5.361549
# >> Epoch 51 finished 	RBM 2 Reconstruction error 5.358977
# >> Epoch 52 finished 	RBM 2 Reconstruction error 5.359929
# >> Epoch 53 finished 	RBM 2 Reconstruction error 5.361602
# >> Epoch 54 finished 	RBM 2 Reconstruction error 5.358598
# >> Epoch 55 finished 	RBM 2 Reconstruction error 5.362124
# >> Epoch 56 finished 	RBM 2 Reconstruction error 5.362683
# >> Epoch 57 finished 	RBM 2 Reconstruction error 5.363968
# >> Epoch 58 finished 	RBM 2 Reconstruction error 5.357890
# >> Epoch 59 finished 	RBM 2 Reconstruction error 5.359038
# >> Epoch 60 finished 	RBM 2 Reconstruction error 5.361931
# >> Epoch 61 finished 	RBM 2 Reconstruction error 5.366724
# >> Epoch 62 finished 	RBM 2 Reconstruction error 5.364858
# >> Epoch 63 finished 	RBM 2 Reconstruction error 5.358669
# >> Epoch 64 finished 	RBM 2 Reconstruction error 5.361531
# >> Epoch 65 finished 	RBM 2 Reconstruction error 5.360386
# >> Epoch 66 finished 	RBM 2 Reconstruction error 5.360821
# >> Epoch 67 finished 	RBM 2 Reconstruction error 5.354843
# >> Epoch 68 finished 	RBM 2 Reconstruction error 5.363444
# >> Epoch 69 finished 	RBM 2 Reconstruction error 5.363579
# >> Epoch 70 finished 	RBM 2 Reconstruction error 5.356626
# >> Epoch 71 finished 	RBM 2 Reconstruction error 5.359631
# >> Epoch 72 finished 	RBM 2 Reconstruction error 5.363481
# >> Epoch 73 finished 	RBM 2 Reconstruction error 5.362183
# >> Epoch 74 finished 	RBM 2 Reconstruction error 5.360366
# >> Epoch 75 finished 	RBM 2 Reconstruction error 5.358057
# >> Epoch 76 finished 	RBM 2 Reconstruction error 5.357996
# >> Epoch 77 finished 	RBM 2 Reconstruction error 5.357491
# >> Epoch 78 finished 	RBM 2 Reconstruction error 5.357072
# >> Epoch 79 finished 	RBM 2 Reconstruction error 5.357924
# >> Epoch 80 finished 	RBM 2 Reconstruction error 5.355231
# >> Epoch 81 finished 	RBM 2 Reconstruction error 5.357725
# >> Epoch 82 finished 	RBM 2 Reconstruction error 5.354848
# >> Epoch 83 finished 	RBM 2 Reconstruction error 5.358885
# >> Epoch 84 finished 	RBM 2 Reconstruction error 5.354421
# >> Epoch 85 finished 	RBM 2 Reconstruction error 5.355459
# >> Epoch 86 finished 	RBM 2 Reconstruction error 5.359586
# >> Epoch 87 finished 	RBM 2 Reconstruction error 5.357360
# >> Epoch 88 finished 	RBM 2 Reconstruction error 5.354240
# >> Epoch 89 finished 	RBM 2 Reconstruction error 5.356984
# >> Epoch 90 finished 	RBM 2 Reconstruction error 5.358841
# >> Epoch 91 finished 	RBM 2 Reconstruction error 5.357589
# >> Epoch 92 finished 	RBM 2 Reconstruction error 5.356325
# >> Epoch 93 finished 	RBM 2 Reconstruction error 5.358153
# >> Epoch 94 finished 	RBM 2 Reconstruction error 5.354336
# >> Epoch 95 finished 	RBM 2 Reconstruction error 5.353550
# >> Epoch 96 finished 	RBM 2 Reconstruction error 5.357139
# >> Epoch 97 finished 	RBM 2 Reconstruction error 5.354850
# >> Epoch 98 finished 	RBM 2 Reconstruction error 5.352351
# >> Epoch 99 finished 	RBM 2 Reconstruction error 5.354228
# >> Epoch 100 finished 	RBM 2 Reconstruction error 5.353873
# Unsupervised training time:  13.092928171157837  seconds
# Finetuning with SVM
# Time fitting the data:  0.023936033248901367
# bins  [0, 1, 2, 3]  digitized 2  [[4 4 4 4]
#  [4 4 4 4]]  mat abs  [[15  6  6 12]
#  [ 9 12  7  8]]
# Test data  Model accuracy : 0.7941176470588235
# Test data  Confusion matrix :
#  [[81  0]
#  [21  0]]
